# %%
import torch
import torchvision
import pytorch_lightning as pl 
from torchvision import transforms
import torchvision.models as models

# %%
from IPython.display import display

# %%
ds = torchvision.datasets.FashionMNIST(root='./data',download=True,)

# %%
dir(ds)
# Out:
# ['__add__',
#  '__annotations__',
#  '__class__',
#  '__class_getitem__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__orig_bases__',
#  '__parameters__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_check_exists',
#  '_check_legacy_exist',
#  '_format_transform_repr',
#  '_is_protocol',
#  '_load_data',
#  '_load_legacy_data',
#  '_repr_indent',
#  'class_to_idx',
#  'classes',
#  'data',
#  'download',
#  'extra_repr',
#  'functions',
#  'mirrors',
#  'processed_folder',
#  'raw_folder',
#  'register_datapipe_as_function',
#  'register_function',
#  'resources',
#  'root',
#  'target_transform',
#  'targets',
#  'test_data',
#  'test_file',
#  'test_labels',
#  'train',
#  'train_data',
#  'train_labels',
#  'training_file',
#  'transform',
#  'transforms']

# %%
ds.classes
# Out:
# ['T-shirt/top',
#  'Trouser',
#  'Pullover',
#  'Dress',
#  'Coat',
#  'Sandal',
#  'Shirt',
#  'Sneaker',
#  'Bag',
#  'Ankle boot']

# %%
# Looking at the first ten examples of the FashionMNIST dataset:
for i in range(0,10):
    img,class_index = ds[i]
    print(ds.classes[class_index])
    display(img.resize((64,64)))
# Out:
# Ankle boot
# <PIL.Image.Image image mode=L size=64x64 at 0x1451A6B5AF0>
# T-shirt/top
# <PIL.Image.Image image mode=L size=64x64 at 0x1451A729AF0>
# T-shirt/top
# <PIL.Image.Image image mode=L size=64x64 at 0x1451A6B5C70>
# Dress
# <PIL.Image.Image image mode=L size=64x64 at 0x1451A6B5C70>
# T-shirt/top
# <PIL.Image.Image image mode=L size=64x64 at 0x1451A729220>
# Pullover
# <PIL.Image.Image image mode=L size=64x64 at 0x14519AC1FD0>
# Sneaker
# <PIL.Image.Image image mode=L size=64x64 at 0x1451A729220>
# Pullover
# <PIL.Image.Image image mode=L size=64x64 at 0x1451A729AF0>
# Sandal
# <PIL.Image.Image image mode=L size=64x64 at 0x1451A729220>
# Sandal
# <PIL.Image.Image image mode=L size=64x64 at 0x14519AC1FD0>

# %%
ds[0][0].size
# Out:
# (28, 28)

# %%
resnet18 = models.resnet18()

# %%
transforms.ToTensor()(img.resize((224,224)).convert('RGB')).unsqueeze(0).shape
# Out:
# torch.Size([1, 3, 224, 224])

# %%
dir(resnet18)
# Out:
# ['T_destination',
#  '__annotations__',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_apply',
#  '_backward_hooks',
#  '_buffers',
#  '_call_impl',
#  '_forward_hooks',
#  '_forward_impl',
#  '_forward_pre_hooks',
#  '_get_backward_hooks',
#  '_get_name',
#  '_is_full_backward_hook',
#  '_load_from_state_dict',
#  '_load_state_dict_pre_hooks',
#  '_make_layer',
#  '_maybe_warn_non_full_backward_hook',
#  '_modules',
#  '_named_members',
#  '_non_persistent_buffers_set',
#  '_norm_layer',
#  '_parameters',
#  '_register_load_state_dict_pre_hook',
#  '_register_state_dict_hook',
#  '_replicate_for_data_parallel',
#  '_save_to_state_dict',
#  '_slow_forward',
#  '_state_dict_hooks',
#  '_version',
#  'add_module',
#  'apply',
#  'avgpool',
#  'base_width',
#  'bfloat16',
#  'bn1',
#  'buffers',
#  'children',
#  'conv1',
#  'cpu',
#  'cuda',
#  'dilation',
#  'double',
#  'dump_patches',
#  'eval',
#  'extra_repr',
#  'fc',
#  'float',
#  'forward',
#  'get_buffer',
#  'get_extra_state',
#  'get_parameter',
#  'get_submodule',
#  'groups',
#  'half',
#  'inplanes',
#  'layer1',
#  'layer2',
#  'layer3',
#  'layer4',
#  'load_state_dict',
#  'maxpool',
#  'modules',
#  'named_buffers',
#  'named_children',
#  'named_modules',
#  'named_parameters',
#  'parameters',
#  'register_backward_hook',
#  'register_buffer',
#  'register_forward_hook',
#  'register_forward_pre_hook',
#  'register_full_backward_hook',
#  'register_parameter',
#  'relu',
#  'requires_grad_',
#  'set_extra_state',
#  'share_memory',
#  'state_dict',
#  'to',
#  'to_empty',
#  'train',
#  'training',
#  'type',
#  'xpu',
#  'zero_grad']

# %%
image_net_classes = {0: 'tench, Tinca tinca',
 1: 'goldfish, Carassius auratus',
 2: 'great white shark, white shark, man-eater, man-eating shark, Carcharodon carcharias',
 3: 'tiger shark, Galeocerdo cuvieri',
 4: 'hammerhead, hammerhead shark',
 5: 'electric ray, crampfish, numbfish, torpedo',
 6: 'stingray',
 7: 'cock',
 8: 'hen',
 9: 'ostrich, Struthio camelus',
 10: 'brambling, Fringilla montifringilla',
 11: 'goldfinch, Carduelis carduelis',
 12: 'house finch, linnet, Carpodacus mexicanus',
 13: 'junco, snowbird',
 14: 'indigo bunting, indigo finch, indigo bird, Passerina cyanea',
 15: 'robin, American robin, Turdus migratorius',
 16: 'bulbul',
 17: 'jay',
 18: 'magpie',
 19: 'chickadee',
 20: 'water ouzel, dipper',
 21: 'kite',
 22: 'bald eagle, American eagle, Haliaeetus leucocephalus',
 23: 'vulture',
 24: 'great grey owl, great gray owl, Strix nebulosa',
 25: 'European fire salamander, Salamandra salamandra',
 26: 'common newt, Triturus vulgaris',
 27: 'eft',
 28: 'spotted salamander, Ambystoma maculatum',
 29: 'axolotl, mud puppy, Ambystoma mexicanum',
 30: 'bullfrog, Rana catesbeiana',
 31: 'tree frog, tree-frog',
 32: 'tailed frog, bell toad, ribbed toad, tailed toad, Ascaphus trui',
 33: 'loggerhead, loggerhead turtle, Caretta caretta',
 34: 'leatherback turtle, leatherback, leathery turtle, Dermochelys coriacea',
 35: 'mud turtle',
 36: 'terrapin',
 37: 'box turtle, box tortoise',
 38: 'banded gecko',
 39: 'common iguana, iguana, Iguana iguana',
 40: 'American chameleon, anole, Anolis carolinensis',
 41: 'whiptail, whiptail lizard',
 42: 'agama',
 43: 'frilled lizard, Chlamydosaurus kingi',
 44: 'alligator lizard',
 45: 'Gila monster, Heloderma suspectum',
 46: 'green lizard, Lacerta viridis',
 47: 'African chameleon, Chamaeleo chamaeleon',
 48: 'Komodo dragon, Komodo lizard, dragon lizard, giant lizard, Varanus komodoensis',
 49: 'African crocodile, Nile crocodile, Crocodylus niloticus',
 50: 'American alligator, Alligator mississipiensis',
 51: 'triceratops',
 52: 'thunder snake, worm snake, Carphophis amoenus',
 53: 'ringneck snake, ring-necked snake, ring snake',
 54: 'hognose snake, puff adder, sand viper',
 55: 'green snake, grass snake',
 56: 'king snake, kingsnake',
 57: 'garter snake, grass snake',
 58: 'water snake',
 59: 'vine snake',
 60: 'night snake, Hypsiglena torquata',
 61: 'boa constrictor, Constrictor constrictor',
 62: 'rock python, rock snake, Python sebae',
 63: 'Indian cobra, Naja naja',
 64: 'green mamba',
 65: 'sea snake',
 66: 'horned viper, cerastes, sand viper, horned asp, Cerastes cornutus',
 67: 'diamondback, diamondback rattlesnake, Crotalus adamanteus',
 68: 'sidewinder, horned rattlesnake, Crotalus cerastes',
 69: 'trilobite',
 70: 'harvestman, daddy longlegs, Phalangium opilio',
 71: 'scorpion',
 72: 'black and gold garden spider, Argiope aurantia',
 73: 'barn spider, Araneus cavaticus',
 74: 'garden spider, Aranea diademata',
 75: 'black widow, Latrodectus mactans',
 76: 'tarantula',
 77: 'wolf spider, hunting spider',
 78: 'tick',
 79: 'centipede',
 80: 'black grouse',
 81: 'ptarmigan',
 82: 'ruffed grouse, partridge, Bonasa umbellus',
 83: 'prairie chicken, prairie grouse, prairie fowl',
 84: 'peacock',
 85: 'quail',
 86: 'partridge',
 87: 'African grey, African gray, Psittacus erithacus',
 88: 'macaw',
 89: 'sulphur-crested cockatoo, Kakatoe galerita, Cacatua galerita',
 90: 'lorikeet',
 91: 'coucal',
 92: 'bee eater',
 93: 'hornbill',
 94: 'hummingbird',
 95: 'jacamar',
 96: 'toucan',
 97: 'drake',
 98: 'red-breasted merganser, Mergus serrator',
 99: 'goose',
 100: 'black swan, Cygnus atratus',
 101: 'tusker',
 102: 'echidna, spiny anteater, anteater',
 103: 'platypus, duckbill, duckbilled platypus, duck-billed platypus, Ornithorhynchus anatinus',
 104: 'wallaby, brush kangaroo',
 105: 'koala, koala bear, kangaroo bear, native bear, Phascolarctos cinereus',
 106: 'wombat',
 107: 'jellyfish',
 108: 'sea anemone, anemone',
 109: 'brain coral',
 110: 'flatworm, platyhelminth',
 111: 'nematode, nematode worm, roundworm',
 112: 'conch',
 113: 'snail',
 114: 'slug',
 115: 'sea slug, nudibranch',
 116: 'chiton, coat-of-mail shell, sea cradle, polyplacophore',
 117: 'chambered nautilus, pearly nautilus, nautilus',
 118: 'Dungeness crab, Cancer magister',
 119: 'rock crab, Cancer irroratus',
 120: 'fiddler crab',
 121: 'king crab, Alaska crab, Alaskan king crab, Alaska king crab, Paralithodes camtschatica',
 122: 'American lobster, Northern lobster, Maine lobster, Homarus americanus',
 123: 'spiny lobster, langouste, rock lobster, crawfish, crayfish, sea crawfish',
 124: 'crayfish, crawfish, crawdad, crawdaddy',
 125: 'hermit crab',
 126: 'isopod',
 127: 'white stork, Ciconia ciconia',
 128: 'black stork, Ciconia nigra',
 129: 'spoonbill',
 130: 'flamingo',
 131: 'little blue heron, Egretta caerulea',
 132: 'American egret, great white heron, Egretta albus',
 133: 'bittern',
 134: 'crane',
 135: 'limpkin, Aramus pictus',
 136: 'European gallinule, Porphyrio porphyrio',
 137: 'American coot, marsh hen, mud hen, water hen, Fulica americana',
 138: 'bustard',
 139: 'ruddy turnstone, Arenaria interpres',
 140: 'red-backed sandpiper, dunlin, Erolia alpina',
 141: 'redshank, Tringa totanus',
 142: 'dowitcher',
 143: 'oystercatcher, oyster catcher',
 144: 'pelican',
 145: 'king penguin, Aptenodytes patagonica',
 146: 'albatross, mollymawk',
 147: 'grey whale, gray whale, devilfish, Eschrichtius gibbosus, Eschrichtius robustus',
 148: 'killer whale, killer, orca, grampus, sea wolf, Orcinus orca',
 149: 'dugong, Dugong dugon',
 150: 'sea lion',
 151: 'Chihuahua',
 152: 'Japanese spaniel',
 153: 'Maltese dog, Maltese terrier, Maltese',
 154: 'Pekinese, Pekingese, Peke',
 155: 'Shih-Tzu',
 156: 'Blenheim spaniel',
 157: 'papillon',
 158: 'toy terrier',
 159: 'Rhodesian ridgeback',
 160: 'Afghan hound, Afghan',
 161: 'basset, basset hound',
 162: 'beagle',
 163: 'bloodhound, sleuthhound',
 164: 'bluetick',
 165: 'black-and-tan coonhound',
 166: 'Walker hound, Walker foxhound',
 167: 'English foxhound',
 168: 'redbone',
 169: 'borzoi, Russian wolfhound',
 170: 'Irish wolfhound',
 171: 'Italian greyhound',
 172: 'whippet',
 173: 'Ibizan hound, Ibizan Podenco',
 174: 'Norwegian elkhound, elkhound',
 175: 'otterhound, otter hound',
 176: 'Saluki, gazelle hound',
 177: 'Scottish deerhound, deerhound',
 178: 'Weimaraner',
 179: 'Staffordshire bullterrier, Staffordshire bull terrier',
 180: 'American Staffordshire terrier, Staffordshire terrier, American pit bull terrier, pit bull terrier',
 181: 'Bedlington terrier',
 182: 'Border terrier',
 183: 'Kerry blue terrier',
 184: 'Irish terrier',
 185: 'Norfolk terrier',
 186: 'Norwich terrier',
 187: 'Yorkshire terrier',
 188: 'wire-haired fox terrier',
 189: 'Lakeland terrier',
 190: 'Sealyham terrier, Sealyham',
 191: 'Airedale, Airedale terrier',
 192: 'cairn, cairn terrier',
 193: 'Australian terrier',
 194: 'Dandie Dinmont, Dandie Dinmont terrier',
 195: 'Boston bull, Boston terrier',
 196: 'miniature schnauzer',
 197: 'giant schnauzer',
 198: 'standard schnauzer',
 199: 'Scotch terrier, Scottish terrier, Scottie',
 200: 'Tibetan terrier, chrysanthemum dog',
 201: 'silky terrier, Sydney silky',
 202: 'soft-coated wheaten terrier',
 203: 'West Highland white terrier',
 204: 'Lhasa, Lhasa apso',
 205: 'flat-coated retriever',
 206: 'curly-coated retriever',
 207: 'golden retriever',
 208: 'Labrador retriever',
 209: 'Chesapeake Bay retriever',
 210: 'German short-haired pointer',
 211: 'vizsla, Hungarian pointer',
 212: 'English setter',
 213: 'Irish setter, red setter',
 214: 'Gordon setter',
 215: 'Brittany spaniel',
 216: 'clumber, clumber spaniel',
 217: 'English springer, English springer spaniel',
 218: 'Welsh springer spaniel',
 219: 'cocker spaniel, English cocker spaniel, cocker',
 220: 'Sussex spaniel',
 221: 'Irish water spaniel',
 222: 'kuvasz',
 223: 'schipperke',
 224: 'groenendael',
 225: 'malinois',
 226: 'briard',
 227: 'kelpie',
 228: 'komondor',
 229: 'Old English sheepdog, bobtail',
 230: 'Shetland sheepdog, Shetland sheep dog, Shetland',
 231: 'collie',
 232: 'Border collie',
 233: 'Bouvier des Flandres, Bouviers des Flandres',
 234: 'Rottweiler',
 235: 'German shepherd, German shepherd dog, German police dog, alsatian',
 236: 'Doberman, Doberman pinscher',
 237: 'miniature pinscher',
 238: 'Greater Swiss Mountain dog',
 239: 'Bernese mountain dog',
 240: 'Appenzeller',
 241: 'EntleBucher',
 242: 'boxer',
 243: 'bull mastiff',
 244: 'Tibetan mastiff',
 245: 'French bulldog',
 246: 'Great Dane',
 247: 'Saint Bernard, St Bernard',
 248: 'Eskimo dog, husky',
 249: 'malamute, malemute, Alaskan malamute',
 250: 'Siberian husky',
 251: 'dalmatian, coach dog, carriage dog',
 252: 'affenpinscher, monkey pinscher, monkey dog',
 253: 'basenji',
 254: 'pug, pug-dog',
 255: 'Leonberg',
 256: 'Newfoundland, Newfoundland dog',
 257: 'Great Pyrenees',
 258: 'Samoyed, Samoyede',
 259: 'Pomeranian',
 260: 'chow, chow chow',
 261: 'keeshond',
 262: 'Brabancon griffon',
 263: 'Pembroke, Pembroke Welsh corgi',
 264: 'Cardigan, Cardigan Welsh corgi',
 265: 'toy poodle',
 266: 'miniature poodle',
 267: 'standard poodle',
 268: 'Mexican hairless',
 269: 'timber wolf, grey wolf, gray wolf, Canis lupus',
 270: 'white wolf, Arctic wolf, Canis lupus tundrarum',
 271: 'red wolf, maned wolf, Canis rufus, Canis niger',
 272: 'coyote, prairie wolf, brush wolf, Canis latrans',
 273: 'dingo, warrigal, warragal, Canis dingo',
 274: 'dhole, Cuon alpinus',
 275: 'African hunting dog, hyena dog, Cape hunting dog, Lycaon pictus',
 276: 'hyena, hyaena',
 277: 'red fox, Vulpes vulpes',
 278: 'kit fox, Vulpes macrotis',
 279: 'Arctic fox, white fox, Alopex lagopus',
 280: 'grey fox, gray fox, Urocyon cinereoargenteus',
 281: 'tabby, tabby cat',
 282: 'tiger cat',
 283: 'Persian cat',
 284: 'Siamese cat, Siamese',
 285: 'Egyptian cat',
 286: 'cougar, puma, catamount, mountain lion, painter, panther, Felis concolor',
 287: 'lynx, catamount',
 288: 'leopard, Panthera pardus',
 289: 'snow leopard, ounce, Panthera uncia',
 290: 'jaguar, panther, Panthera onca, Felis onca',
 291: 'lion, king of beasts, Panthera leo',
 292: 'tiger, Panthera tigris',
 293: 'cheetah, chetah, Acinonyx jubatus',
 294: 'brown bear, bruin, Ursus arctos',
 295: 'American black bear, black bear, Ursus americanus, Euarctos americanus',
 296: 'ice bear, polar bear, Ursus Maritimus, Thalarctos maritimus',
 297: 'sloth bear, Melursus ursinus, Ursus ursinus',
 298: 'mongoose',
 299: 'meerkat, mierkat',
 300: 'tiger beetle',
 301: 'ladybug, ladybeetle, lady beetle, ladybird, ladybird beetle',
 302: 'ground beetle, carabid beetle',
 303: 'long-horned beetle, longicorn, longicorn beetle',
 304: 'leaf beetle, chrysomelid',
 305: 'dung beetle',
 306: 'rhinoceros beetle',
 307: 'weevil',
 308: 'fly',
 309: 'bee',
 310: 'ant, emmet, pismire',
 311: 'grasshopper, hopper',
 312: 'cricket',
 313: 'walking stick, walkingstick, stick insect',
 314: 'cockroach, roach',
 315: 'mantis, mantid',
 316: 'cicada, cicala',
 317: 'leafhopper',
 318: 'lacewing, lacewing fly',
 319: "dragonfly, darning needle, devil's darning needle, sewing needle, snake feeder, snake doctor, mosquito hawk, skeeter hawk",
 320: 'damselfly',
 321: 'admiral',
 322: 'ringlet, ringlet butterfly',
 323: 'monarch, monarch butterfly, milkweed butterfly, Danaus plexippus',
 324: 'cabbage butterfly',
 325: 'sulphur butterfly, sulfur butterfly',
 326: 'lycaenid, lycaenid butterfly',
 327: 'starfish, sea star',
 328: 'sea urchin',
 329: 'sea cucumber, holothurian',
 330: 'wood rabbit, cottontail, cottontail rabbit',
 331: 'hare',
 332: 'Angora, Angora rabbit',
 333: 'hamster',
 334: 'porcupine, hedgehog',
 335: 'fox squirrel, eastern fox squirrel, Sciurus niger',
 336: 'marmot',
 337: 'beaver',
 338: 'guinea pig, Cavia cobaya',
 339: 'sorrel',
 340: 'zebra',
 341: 'hog, pig, grunter, squealer, Sus scrofa',
 342: 'wild boar, boar, Sus scrofa',
 343: 'warthog',
 344: 'hippopotamus, hippo, river horse, Hippopotamus amphibius',
 345: 'ox',
 346: 'water buffalo, water ox, Asiatic buffalo, Bubalus bubalis',
 347: 'bison',
 348: 'ram, tup',
 349: 'bighorn, bighorn sheep, cimarron, Rocky Mountain bighorn, Rocky Mountain sheep, Ovis canadensis',
 350: 'ibex, Capra ibex',
 351: 'hartebeest',
 352: 'impala, Aepyceros melampus',
 353: 'gazelle',
 354: 'Arabian camel, dromedary, Camelus dromedarius',
 355: 'llama',
 356: 'weasel',
 357: 'mink',
 358: 'polecat, fitch, foulmart, foumart, Mustela putorius',
 359: 'black-footed ferret, ferret, Mustela nigripes',
 360: 'otter',
 361: 'skunk, polecat, wood pussy',
 362: 'badger',
 363: 'armadillo',
 364: 'three-toed sloth, ai, Bradypus tridactylus',
 365: 'orangutan, orang, orangutang, Pongo pygmaeus',
 366: 'gorilla, Gorilla gorilla',
 367: 'chimpanzee, chimp, Pan troglodytes',
 368: 'gibbon, Hylobates lar',
 369: 'siamang, Hylobates syndactylus, Symphalangus syndactylus',
 370: 'guenon, guenon monkey',
 371: 'patas, hussar monkey, Erythrocebus patas',
 372: 'baboon',
 373: 'macaque',
 374: 'langur',
 375: 'colobus, colobus monkey',
 376: 'proboscis monkey, Nasalis larvatus',
 377: 'marmoset',
 378: 'capuchin, ringtail, Cebus capucinus',
 379: 'howler monkey, howler',
 380: 'titi, titi monkey',
 381: 'spider monkey, Ateles geoffroyi',
 382: 'squirrel monkey, Saimiri sciureus',
 383: 'Madagascar cat, ring-tailed lemur, Lemur catta',
 384: 'indri, indris, Indri indri, Indri brevicaudatus',
 385: 'Indian elephant, Elephas maximus',
 386: 'African elephant, Loxodonta africana',
 387: 'lesser panda, red panda, panda, bear cat, cat bear, Ailurus fulgens',
 388: 'giant panda, panda, panda bear, coon bear, Ailuropoda melanoleuca',
 389: 'barracouta, snoek',
 390: 'eel',
 391: 'coho, cohoe, coho salmon, blue jack, silver salmon, Oncorhynchus kisutch',
 392: 'rock beauty, Holocanthus tricolor',
 393: 'anemone fish',
 394: 'sturgeon',
 395: 'gar, garfish, garpike, billfish, Lepisosteus osseus',
 396: 'lionfish',
 397: 'puffer, pufferfish, blowfish, globefish',
 398: 'abacus',
 399: 'abaya',
 400: "academic gown, academic robe, judge's robe",
 401: 'accordion, piano accordion, squeeze box',
 402: 'acoustic guitar',
 403: 'aircraft carrier, carrier, flattop, attack aircraft carrier',
 404: 'airliner',
 405: 'airship, dirigible',
 406: 'altar',
 407: 'ambulance',
 408: 'amphibian, amphibious vehicle',
 409: 'analog clock',
 410: 'apiary, bee house',
 411: 'apron',
 412: 'ashcan, trash can, garbage can, wastebin, ash bin, ash-bin, ashbin, dustbin, trash barrel, trash bin',
 413: 'assault rifle, assault gun',
 414: 'backpack, back pack, knapsack, packsack, rucksack, haversack',
 415: 'bakery, bakeshop, bakehouse',
 416: 'balance beam, beam',
 417: 'balloon',
 418: 'ballpoint, ballpoint pen, ballpen, Biro',
 419: 'Band Aid',
 420: 'banjo',
 421: 'bannister, banister, balustrade, balusters, handrail',
 422: 'barbell',
 423: 'barber chair',
 424: 'barbershop',
 425: 'barn',
 426: 'barometer',
 427: 'barrel, cask',
 428: 'barrow, garden cart, lawn cart, wheelbarrow',
 429: 'baseball',
 430: 'basketball',
 431: 'bassinet',
 432: 'bassoon',
 433: 'bathing cap, swimming cap',
 434: 'bath towel',
 435: 'bathtub, bathing tub, bath, tub',
 436: 'beach wagon, station wagon, wagon, estate car, beach waggon, station waggon, waggon',
 437: 'beacon, lighthouse, beacon light, pharos',
 438: 'beaker',
 439: 'bearskin, busby, shako',
 440: 'beer bottle',
 441: 'beer glass',
 442: 'bell cote, bell cot',
 443: 'bib',
 444: 'bicycle-built-for-two, tandem bicycle, tandem',
 445: 'bikini, two-piece',
 446: 'binder, ring-binder',
 447: 'binoculars, field glasses, opera glasses',
 448: 'birdhouse',
 449: 'boathouse',
 450: 'bobsled, bobsleigh, bob',
 451: 'bolo tie, bolo, bola tie, bola',
 452: 'bonnet, poke bonnet',
 453: 'bookcase',
 454: 'bookshop, bookstore, bookstall',
 455: 'bottlecap',
 456: 'bow',
 457: 'bow tie, bow-tie, bowtie',
 458: 'brass, memorial tablet, plaque',
 459: 'brassiere, bra, bandeau',
 460: 'breakwater, groin, groyne, mole, bulwark, seawall, jetty',
 461: 'breastplate, aegis, egis',
 462: 'broom',
 463: 'bucket, pail',
 464: 'buckle',
 465: 'bulletproof vest',
 466: 'bullet train, bullet',
 467: 'butcher shop, meat market',
 468: 'cab, hack, taxi, taxicab',
 469: 'caldron, cauldron',
 470: 'candle, taper, wax light',
 471: 'cannon',
 472: 'canoe',
 473: 'can opener, tin opener',
 474: 'cardigan',
 475: 'car mirror',
 476: 'carousel, carrousel, merry-go-round, roundabout, whirligig',
 477: "carpenter's kit, tool kit",
 478: 'carton',
 479: 'car wheel',
 480: 'cash machine, cash dispenser, automated teller machine, automatic teller machine, automated teller, automatic teller, ATM',
 481: 'cassette',
 482: 'cassette player',
 483: 'castle',
 484: 'catamaran',
 485: 'CD player',
 486: 'cello, violoncello',
 487: 'cellular telephone, cellular phone, cellphone, cell, mobile phone',
 488: 'chain',
 489: 'chainlink fence',
 490: 'chain mail, ring mail, mail, chain armor, chain armour, ring armor, ring armour',
 491: 'chain saw, chainsaw',
 492: 'chest',
 493: 'chiffonier, commode',
 494: 'chime, bell, gong',
 495: 'china cabinet, china closet',
 496: 'Christmas stocking',
 497: 'church, church building',
 498: 'cinema, movie theater, movie theatre, movie house, picture palace',
 499: 'cleaver, meat cleaver, chopper',
 500: 'cliff dwelling',
 501: 'cloak',
 502: 'clog, geta, patten, sabot',
 503: 'cocktail shaker',
 504: 'coffee mug',
 505: 'coffeepot',
 506: 'coil, spiral, volute, whorl, helix',
 507: 'combination lock',
 508: 'computer keyboard, keypad',
 509: 'confectionery, confectionary, candy store',
 510: 'container ship, containership, container vessel',
 511: 'convertible',
 512: 'corkscrew, bottle screw',
 513: 'cornet, horn, trumpet, trump',
 514: 'cowboy boot',
 515: 'cowboy hat, ten-gallon hat',
 516: 'cradle',
 517: 'crane',
 518: 'crash helmet',
 519: 'crate',
 520: 'crib, cot',
 521: 'Crock Pot',
 522: 'croquet ball',
 523: 'crutch',
 524: 'cuirass',
 525: 'dam, dike, dyke',
 526: 'desk',
 527: 'desktop computer',
 528: 'dial telephone, dial phone',
 529: 'diaper, nappy, napkin',
 530: 'digital clock',
 531: 'digital watch',
 532: 'dining table, board',
 533: 'dishrag, dishcloth',
 534: 'dishwasher, dish washer, dishwashing machine',
 535: 'disk brake, disc brake',
 536: 'dock, dockage, docking facility',
 537: 'dogsled, dog sled, dog sleigh',
 538: 'dome',
 539: 'doormat, welcome mat',
 540: 'drilling platform, offshore rig',
 541: 'drum, membranophone, tympan',
 542: 'drumstick',
 543: 'dumbbell',
 544: 'Dutch oven',
 545: 'electric fan, blower',
 546: 'electric guitar',
 547: 'electric locomotive',
 548: 'entertainment center',
 549: 'envelope',
 550: 'espresso maker',
 551: 'face powder',
 552: 'feather boa, boa',
 553: 'file, file cabinet, filing cabinet',
 554: 'fireboat',
 555: 'fire engine, fire truck',
 556: 'fire screen, fireguard',
 557: 'flagpole, flagstaff',
 558: 'flute, transverse flute',
 559: 'folding chair',
 560: 'football helmet',
 561: 'forklift',
 562: 'fountain',
 563: 'fountain pen',
 564: 'four-poster',
 565: 'freight car',
 566: 'French horn, horn',
 567: 'frying pan, frypan, skillet',
 568: 'fur coat',
 569: 'garbage truck, dustcart',
 570: 'gasmask, respirator, gas helmet',
 571: 'gas pump, gasoline pump, petrol pump, island dispenser',
 572: 'goblet',
 573: 'go-kart',
 574: 'golf ball',
 575: 'golfcart, golf cart',
 576: 'gondola',
 577: 'gong, tam-tam',
 578: 'gown',
 579: 'grand piano, grand',
 580: 'greenhouse, nursery, glasshouse',
 581: 'grille, radiator grille',
 582: 'grocery store, grocery, food market, market',
 583: 'guillotine',
 584: 'hair slide',
 585: 'hair spray',
 586: 'half track',
 587: 'hammer',
 588: 'hamper',
 589: 'hand blower, blow dryer, blow drier, hair dryer, hair drier',
 590: 'hand-held computer, hand-held microcomputer',
 591: 'handkerchief, hankie, hanky, hankey',
 592: 'hard disc, hard disk, fixed disk',
 593: 'harmonica, mouth organ, harp, mouth harp',
 594: 'harp',
 595: 'harvester, reaper',
 596: 'hatchet',
 597: 'holster',
 598: 'home theater, home theatre',
 599: 'honeycomb',
 600: 'hook, claw',
 601: 'hoopskirt, crinoline',
 602: 'horizontal bar, high bar',
 603: 'horse cart, horse-cart',
 604: 'hourglass',
 605: 'iPod',
 606: 'iron, smoothing iron',
 607: "jack-o'-lantern",
 608: 'jean, blue jean, denim',
 609: 'jeep, landrover',
 610: 'jersey, T-shirt, tee shirt',
 611: 'jigsaw puzzle',
 612: 'jinrikisha, ricksha, rickshaw',
 613: 'joystick',
 614: 'kimono',
 615: 'knee pad',
 616: 'knot',
 617: 'lab coat, laboratory coat',
 618: 'ladle',
 619: 'lampshade, lamp shade',
 620: 'laptop, laptop computer',
 621: 'lawn mower, mower',
 622: 'lens cap, lens cover',
 623: 'letter opener, paper knife, paperknife',
 624: 'library',
 625: 'lifeboat',
 626: 'lighter, light, igniter, ignitor',
 627: 'limousine, limo',
 628: 'liner, ocean liner',
 629: 'lipstick, lip rouge',
 630: 'Loafer',
 631: 'lotion',
 632: 'loudspeaker, speaker, speaker unit, loudspeaker system, speaker system',
 633: "loupe, jeweler's loupe",
 634: 'lumbermill, sawmill',
 635: 'magnetic compass',
 636: 'mailbag, postbag',
 637: 'mailbox, letter box',
 638: 'maillot',
 639: 'maillot, tank suit',
 640: 'manhole cover',
 641: 'maraca',
 642: 'marimba, xylophone',
 643: 'mask',
 644: 'matchstick',
 645: 'maypole',
 646: 'maze, labyrinth',
 647: 'measuring cup',
 648: 'medicine chest, medicine cabinet',
 649: 'megalith, megalithic structure',
 650: 'microphone, mike',
 651: 'microwave, microwave oven',
 652: 'military uniform',
 653: 'milk can',
 654: 'minibus',
 655: 'miniskirt, mini',
 656: 'minivan',
 657: 'missile',
 658: 'mitten',
 659: 'mixing bowl',
 660: 'mobile home, manufactured home',
 661: 'Model T',
 662: 'modem',
 663: 'monastery',
 664: 'monitor',
 665: 'moped',
 666: 'mortar',
 667: 'mortarboard',
 668: 'mosque',
 669: 'mosquito net',
 670: 'motor scooter, scooter',
 671: 'mountain bike, all-terrain bike, off-roader',
 672: 'mountain tent',
 673: 'mouse, computer mouse',
 674: 'mousetrap',
 675: 'moving van',
 676: 'muzzle',
 677: 'nail',
 678: 'neck brace',
 679: 'necklace',
 680: 'nipple',
 681: 'notebook, notebook computer',
 682: 'obelisk',
 683: 'oboe, hautboy, hautbois',
 684: 'ocarina, sweet potato',
 685: 'odometer, hodometer, mileometer, milometer',
 686: 'oil filter',
 687: 'organ, pipe organ',
 688: 'oscilloscope, scope, cathode-ray oscilloscope, CRO',
 689: 'overskirt',
 690: 'oxcart',
 691: 'oxygen mask',
 692: 'packet',
 693: 'paddle, boat paddle',
 694: 'paddlewheel, paddle wheel',
 695: 'padlock',
 696: 'paintbrush',
 697: "pajama, pyjama, pj's, jammies",
 698: 'palace',
 699: 'panpipe, pandean pipe, syrinx',
 700: 'paper towel',
 701: 'parachute, chute',
 702: 'parallel bars, bars',
 703: 'park bench',
 704: 'parking meter',
 705: 'passenger car, coach, carriage',
 706: 'patio, terrace',
 707: 'pay-phone, pay-station',
 708: 'pedestal, plinth, footstall',
 709: 'pencil box, pencil case',
 710: 'pencil sharpener',
 711: 'perfume, essence',
 712: 'Petri dish',
 713: 'photocopier',
 714: 'pick, plectrum, plectron',
 715: 'pickelhaube',
 716: 'picket fence, paling',
 717: 'pickup, pickup truck',
 718: 'pier',
 719: 'piggy bank, penny bank',
 720: 'pill bottle',
 721: 'pillow',
 722: 'ping-pong ball',
 723: 'pinwheel',
 724: 'pirate, pirate ship',
 725: 'pitcher, ewer',
 726: "plane, carpenter's plane, woodworking plane",
 727: 'planetarium',
 728: 'plastic bag',
 729: 'plate rack',
 730: 'plow, plough',
 731: "plunger, plumber's helper",
 732: 'Polaroid camera, Polaroid Land camera',
 733: 'pole',
 734: 'police van, police wagon, paddy wagon, patrol wagon, wagon, black Maria',
 735: 'poncho',
 736: 'pool table, billiard table, snooker table',
 737: 'pop bottle, soda bottle',
 738: 'pot, flowerpot',
 739: "potter's wheel",
 740: 'power drill',
 741: 'prayer rug, prayer mat',
 742: 'printer',
 743: 'prison, prison house',
 744: 'projectile, missile',
 745: 'projector',
 746: 'puck, hockey puck',
 747: 'punching bag, punch bag, punching ball, punchball',
 748: 'purse',
 749: 'quill, quill pen',
 750: 'quilt, comforter, comfort, puff',
 751: 'racer, race car, racing car',
 752: 'racket, racquet',
 753: 'radiator',
 754: 'radio, wireless',
 755: 'radio telescope, radio reflector',
 756: 'rain barrel',
 757: 'recreational vehicle, RV, R.V.',
 758: 'reel',
 759: 'reflex camera',
 760: 'refrigerator, icebox',
 761: 'remote control, remote',
 762: 'restaurant, eating house, eating place, eatery',
 763: 'revolver, six-gun, six-shooter',
 764: 'rifle',
 765: 'rocking chair, rocker',
 766: 'rotisserie',
 767: 'rubber eraser, rubber, pencil eraser',
 768: 'rugby ball',
 769: 'rule, ruler',
 770: 'running shoe',
 771: 'safe',
 772: 'safety pin',
 773: 'saltshaker, salt shaker',
 774: 'sandal',
 775: 'sarong',
 776: 'sax, saxophone',
 777: 'scabbard',
 778: 'scale, weighing machine',
 779: 'school bus',
 780: 'schooner',
 781: 'scoreboard',
 782: 'screen, CRT screen',
 783: 'screw',
 784: 'screwdriver',
 785: 'seat belt, seatbelt',
 786: 'sewing machine',
 787: 'shield, buckler',
 788: 'shoe shop, shoe-shop, shoe store',
 789: 'shoji',
 790: 'shopping basket',
 791: 'shopping cart',
 792: 'shovel',
 793: 'shower cap',
 794: 'shower curtain',
 795: 'ski',
 796: 'ski mask',
 797: 'sleeping bag',
 798: 'slide rule, slipstick',
 799: 'sliding door',
 800: 'slot, one-armed bandit',
 801: 'snorkel',
 802: 'snowmobile',
 803: 'snowplow, snowplough',
 804: 'soap dispenser',
 805: 'soccer ball',
 806: 'sock',
 807: 'solar dish, solar collector, solar furnace',
 808: 'sombrero',
 809: 'soup bowl',
 810: 'space bar',
 811: 'space heater',
 812: 'space shuttle',
 813: 'spatula',
 814: 'speedboat',
 815: "spider web, spider's web",
 816: 'spindle',
 817: 'sports car, sport car',
 818: 'spotlight, spot',
 819: 'stage',
 820: 'steam locomotive',
 821: 'steel arch bridge',
 822: 'steel drum',
 823: 'stethoscope',
 824: 'stole',
 825: 'stone wall',
 826: 'stopwatch, stop watch',
 827: 'stove',
 828: 'strainer',
 829: 'streetcar, tram, tramcar, trolley, trolley car',
 830: 'stretcher',
 831: 'studio couch, day bed',
 832: 'stupa, tope',
 833: 'submarine, pigboat, sub, U-boat',
 834: 'suit, suit of clothes',
 835: 'sundial',
 836: 'sunglass',
 837: 'sunglasses, dark glasses, shades',
 838: 'sunscreen, sunblock, sun blocker',
 839: 'suspension bridge',
 840: 'swab, swob, mop',
 841: 'sweatshirt',
 842: 'swimming trunks, bathing trunks',
 843: 'swing',
 844: 'switch, electric switch, electrical switch',
 845: 'syringe',
 846: 'table lamp',
 847: 'tank, army tank, armored combat vehicle, armoured combat vehicle',
 848: 'tape player',
 849: 'teapot',
 850: 'teddy, teddy bear',
 851: 'television, television system',
 852: 'tennis ball',
 853: 'thatch, thatched roof',
 854: 'theater curtain, theatre curtain',
 855: 'thimble',
 856: 'thresher, thrasher, threshing machine',
 857: 'throne',
 858: 'tile roof',
 859: 'toaster',
 860: 'tobacco shop, tobacconist shop, tobacconist',
 861: 'toilet seat',
 862: 'torch',
 863: 'totem pole',
 864: 'tow truck, tow car, wrecker',
 865: 'toyshop',
 866: 'tractor',
 867: 'trailer truck, tractor trailer, trucking rig, rig, articulated lorry, semi',
 868: 'tray',
 869: 'trench coat',
 870: 'tricycle, trike, velocipede',
 871: 'trimaran',
 872: 'tripod',
 873: 'triumphal arch',
 874: 'trolleybus, trolley coach, trackless trolley',
 875: 'trombone',
 876: 'tub, vat',
 877: 'turnstile',
 878: 'typewriter keyboard',
 879: 'umbrella',
 880: 'unicycle, monocycle',
 881: 'upright, upright piano',
 882: 'vacuum, vacuum cleaner',
 883: 'vase',
 884: 'vault',
 885: 'velvet',
 886: 'vending machine',
 887: 'vestment',
 888: 'viaduct',
 889: 'violin, fiddle',
 890: 'volleyball',
 891: 'waffle iron',
 892: 'wall clock',
 893: 'wallet, billfold, notecase, pocketbook',
 894: 'wardrobe, closet, press',
 895: 'warplane, military plane',
 896: 'washbasin, handbasin, washbowl, lavabo, wash-hand basin',
 897: 'washer, automatic washer, washing machine',
 898: 'water bottle',
 899: 'water jug',
 900: 'water tower',
 901: 'whiskey jug',
 902: 'whistle',
 903: 'wig',
 904: 'window screen',
 905: 'window shade',
 906: 'Windsor tie',
 907: 'wine bottle',
 908: 'wing',
 909: 'wok',
 910: 'wooden spoon',
 911: 'wool, woolen, woollen',
 912: 'worm fence, snake fence, snake-rail fence, Virginia fence',
 913: 'wreck',
 914: 'yawl',
 915: 'yurt',
 916: 'web site, website, internet site, site',
 917: 'comic book',
 918: 'crossword puzzle, crossword',
 919: 'street sign',
 920: 'traffic light, traffic signal, stoplight',
 921: 'book jacket, dust cover, dust jacket, dust wrapper',
 922: 'menu',
 923: 'plate',
 924: 'guacamole',
 925: 'consomme',
 926: 'hot pot, hotpot',
 927: 'trifle',
 928: 'ice cream, icecream',
 929: 'ice lolly, lolly, lollipop, popsicle',
 930: 'French loaf',
 931: 'bagel, beigel',
 932: 'pretzel',
 933: 'cheeseburger',
 934: 'hotdog, hot dog, red hot',
 935: 'mashed potato',
 936: 'head cabbage',
 937: 'broccoli',
 938: 'cauliflower',
 939: 'zucchini, courgette',
 940: 'spaghetti squash',
 941: 'acorn squash',
 942: 'butternut squash',
 943: 'cucumber, cuke',
 944: 'artichoke, globe artichoke',
 945: 'bell pepper',
 946: 'cardoon',
 947: 'mushroom',
 948: 'Granny Smith',
 949: 'strawberry',
 950: 'orange',
 951: 'lemon',
 952: 'fig',
 953: 'pineapple, ananas',
 954: 'banana',
 955: 'jackfruit, jak, jack',
 956: 'custard apple',
 957: 'pomegranate',
 958: 'hay',
 959: 'carbonara',
 960: 'chocolate sauce, chocolate syrup',
 961: 'dough',
 962: 'meat loaf, meatloaf',
 963: 'pizza, pizza pie',
 964: 'potpie',
 965: 'burrito',
 966: 'red wine',
 967: 'espresso',
 968: 'cup',
 969: 'eggnog',
 970: 'alp',
 971: 'bubble',
 972: 'cliff, drop, drop-off',
 973: 'coral reef',
 974: 'geyser',
 975: 'lakeside, lakeshore',
 976: 'promontory, headland, head, foreland',
 977: 'sandbar, sand bar',
 978: 'seashore, coast, seacoast, sea-coast',
 979: 'valley, vale',
 980: 'volcano',
 981: 'ballplayer, baseball player',
 982: 'groom, bridegroom',
 983: 'scuba diver',
 984: 'rapeseed',
 985: 'daisy',
 986: "yellow lady's slipper, yellow lady-slipper, Cypripedium calceolus, Cypripedium parviflorum",
 987: 'corn',
 988: 'acorn',
 989: 'hip, rose hip, rosehip',
 990: 'buckeye, horse chestnut, conker',
 991: 'coral fungus',
 992: 'agaric',
 993: 'gyromitra',
 994: 'stinkhorn, carrion fungus',
 995: 'earthstar',
 996: 'hen-of-the-woods, hen of the woods, Polyporus frondosus, Grifola frondosa',
 997: 'bolete',
 998: 'ear, spike, capitulum',
 999: 'toilet tissue, toilet paper, bathroom tissue'}

# %%
image_net_classes[int(resnet18(transforms.ToTensor()(img.resize((224,224)).convert('RGB')).unsqueeze(0)).argmax())]
# Out:
# 'grocery store, grocery, food market, market'

# %%
# resnet18 classifies the shoe is a dog => heavy down-scaling of images makes imagenet kind of useless!

# %%
from torch import nn
from torch.functional import F
class Block(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(Block, self).__init__()

        self.skip = nn.Sequential()

        if stride != 1 or in_channels != out_channels:
            self.skip = nn.Sequential(
            nn.Conv2d(in_channels=in_channels, out_channels=out_channels, kernel_size=1, stride=stride, bias=False),
            nn.BatchNorm2d(out_channels))
        else:
            self.skip = None

        self.block = nn.Sequential(
            nn.Conv2d(in_channels=in_channels, out_channels=out_channels, kernel_size=3, padding=1, stride=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
            nn.Conv2d(in_channels=out_channels, out_channels=out_channels, kernel_size=3, padding=1, stride=1, bias=False),
            nn.BatchNorm2d(out_channels))

    def forward(self, x):
        identity = x
        out = self.block(x)

        if self.skip is not None:
            identity = self.skip(x)

            out += identity
        
        out = F.relu(out)

        return out

# %%
# Extremely simple toy cnn
simple_cnn = nn.Sequential(Block(3,6),Block(6,12),Block(12,24),nn.Flatten(),nn.Linear((28)*(28)*24,len(ds.classes)))

# %%
def load_image(img):
    return transforms.ToTensor()(img.convert('RGB'))
simple_cnn.skip = None

# %%
trainer = pl.Trainer(gpus=1)
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs

# %%
from torch.utils.data import DataLoader,Dataset

# %%
class MyDataset(Dataset):
    def __init__(self):
        self.ds = torchvision.datasets.FashionMNIST(root='./data',download=True,)
        
    def load_image(self,img):
        return transforms.ToTensor()(img.convert('RGB'))
        
    def __get__(self,idx):
        tup = self.ds[idx]
        return self.load_image(tup[0]),tup[1]
    
    def __getitem__(self,idx):
        return self.__get__(idx)
    
    def __len__(self):
        return len(self.ds)//10
train_ds = MyDataset()

# %%
len(train_ds)
# Out:
# 6000

# %%
train_dl = DataLoader(train_ds,num_workers=2,)

# %%
class ModelWrapper(pl.LightningModule):
    def __init__(self,net):
        super().__init__()
        self.net = net
    def forward(self,x):
        return self.net.forward(x)
    
    def training_step(self,batch, batch_idx):
        x, y = batch
        y_hat = self(x)
        loss = F.cross_entropy(y_hat, y)
        return loss
    
    ## TODO : implement a validation_step method!!
    def validation_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self(x)
        loss = F.cross_entropy(y_hat, y)
   
        return loss
    
    def configure_optimizers(self):
        return torch.optim.Adam(self.parameters(), lr=0.01)

# %%
model = ModelWrapper(simple_cnn)
trainer.fit(model,train_dl,train_dl,)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type       | Params
# ------------------------------------
# 0 | net  | Sequential | 199 K
# ------------------------------------
# 199 K     Trainable params
# 0         Non-trainable params
# 199 K     Total params
# 0.796     Total estimated model params size (MB)
# C:\Users\janma\anaconda3\envs\frankenbody\lib\site-packages\pytorch_lightning\callbacks\model_checkpoint.py:617: UserWarning: Checkpoint directory C:\Users\janma\Documents\bayer_challenge\presentation\notebooks\lightning_logs\version_3\checkpoints exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
# Validation sanity check: 0it [00:00, ?it/s]
# C:\Users\janma\anaconda3\envs\frankenbody\lib\site-packages\pytorch_lightning\trainer\data_loading.py:110: UserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 4 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# val_loss tensor(0.0960, device='cuda:0')
# val_loss tensor(0.0043, device='cuda:0')
# C:\Users\janma\anaconda3\envs\frankenbody\lib\site-packages\pytorch_lightning\trainer\data_loading.py:110: UserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 4 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# val_loss tensor(0.1879, device='cuda:0')
# val_loss tensor(0.0036, device='cuda:0')
# val_loss tensor(1.9585, device='cuda:0')
# val_loss tensor(0.7873, device='cuda:0')
# val_loss tensor(1.8962, device='cuda:0')
# val_loss tensor(0.0147, device='cuda:0')
# val_loss tensor(0.8783, device='cuda:0')
# val_loss tensor(0.0531, device='cuda:0')
# val_loss tensor(2.1458e-06, device='cuda:0')
# val_loss tensor(2.3842e-07, device='cuda:0')
# val_loss tensor(0.0073, device='cuda:0')
# val_loss tensor(3.1651, device='cuda:0')
# val_loss tensor(0.0018, device='cuda:0')
# val_loss tensor(0.0858, device='cuda:0')
# val_loss tensor(0.0083, device='cuda:0')
# val_loss tensor(0.0017, device='cuda:0')
# val_loss tensor(0.0016, device='cuda:0')
# val_loss tensor(0.0053, device='cuda:0')
# val_loss tensor(3.1374, device='cuda:0')
# val_loss tensor(0.0149, device='cuda:0')
# val_loss tensor(0.0117, device='cuda:0')
# val_loss tensor(0.5269, device='cuda:0')
# val_loss tensor(0.1400, device='cuda:0')
# val_loss tensor(0.0016, device='cuda:0')
# val_loss tensor(0.9837, device='cuda:0')
# val_loss tensor(0.0291, device='cuda:0')
# val_loss tensor(0.0245, device='cuda:0')
# val_loss tensor(0.0552, device='cuda:0')
# val_loss tensor(0.1533, device='cuda:0')
# val_loss tensor(0.0078, device='cuda:0')
# val_loss tensor(0.0109, device='cuda:0')
# val_loss tensor(0.4245, device='cuda:0')
# val_loss tensor(2.7646, device='cuda:0')
# val_loss tensor(0.0936, device='cuda:0')
# val_loss tensor(0.0296, device='cuda:0')
# val_loss tensor(3.4689e-05, device='cuda:0')
# val_loss tensor(0.0005, device='cuda:0')
# val_loss tensor(0.0029, device='cuda:0')
# val_loss tensor(0.0003, device='cuda:0')
# val_loss tensor(0.0427, device='cuda:0')
# val_loss tensor(0.1661, device='cuda:0')
# val_loss tensor(0.0615, device='cuda:0')
# val_loss tensor(0.0441, device='cuda:0')
# val_loss tensor(0.0079, device='cuda:0')
# val_loss tensor(0.7322, device='cuda:0')
# val_loss tensor(0.4317, device='cuda:0')
# val_loss tensor(0.0007, device='cuda:0')
# val_loss tensor(0.1070, device='cuda:0')
# val_loss tensor(0.0057, device='cuda:0')
# val_loss tensor(0.0042, device='cuda:0')
# val_loss tensor(0.0167, device='cuda:0')
# val_loss tensor(0.0415, device='cuda:0')
# val_loss tensor(0.0010, device='cuda:0')
# val_loss tensor(0.1852, device='cuda:0')
# val_loss tensor(0.2261, device='cuda:0')
# val_loss tensor(1.7122, device='cuda:0')
# val_loss tensor(3.7284, device='cuda:0')
# val_loss tensor(0.2406, device='cuda:0')
# val_loss tensor(0.0962, device='cuda:0')
# val_loss tensor(0.8177, device='cuda:0')
# val_loss tensor(5.6028e-06, device='cuda:0')
# val_loss tensor(0.0241, device='cuda:0')
# val_loss tensor(1.6212e-05, device='cuda:0')
# val_loss tensor(0.7910, device='cuda:0')
# val_loss tensor(0.0224, device='cuda:0')
# val_loss tensor(0.1293, device='cuda:0')
# val_loss tensor(0.0029, device='cuda:0')
# val_loss tensor(0.3679, device='cuda:0')
# val_loss tensor(0.0094, device='cuda:0')
# val_loss tensor(0.0011, device='cuda:0')
# val_loss tensor(4.5475, device='cuda:0')
# val_loss tensor(0.0041, device='cuda:0')
# val_loss tensor(0.2796, device='cuda:0')
# val_loss tensor(0.3533, device='cuda:0')
# val_loss tensor(0.0006, device='cuda:0')
# val_loss tensor(0.0104, device='cuda:0')
# val_loss tensor(0.7185, device='cuda:0')
# val_loss tensor(0.7076, device='cuda:0')
# val_loss tensor(0.0018, device='cuda:0')
# val_loss tensor(1.3281, device='cuda:0')
# val_loss tensor(0.0002, device='cuda:0')
# val_loss tensor(0.0214, device='cuda:0')
# val_loss tensor(0., device='cuda:0')
# val_loss tensor(0.0009, device='cuda:0')
# val_loss tensor(0.7921, device='cuda:0')
# val_loss tensor(0.0051, device='cuda:0')
# val_loss tensor(0.0002, device='cuda:0')
# val_loss tensor(0.0146, device='cuda:0')
# val_loss tensor(0.1752, device='cuda:0')
# val_loss tensor(0.6323, device='cuda:0')
# val_loss tensor(0.1454, device='cuda:0')
# val_loss tensor(0.1421, device='cuda:0')
# val_loss tensor(2.5279, device='cuda:0')
# val_loss tensor(0.1573, device='cuda:0')
# val_loss tensor(0.3786, device='cuda:0')
# val_loss tensor(0.1850, device='cuda:0')
# val_loss tensor(0.0714, device='cuda:0')
# val_loss tensor(0.0002, device='cuda:0')
# val_loss tensor(0.0012, device='cuda:0')
# val_loss tensor(3.4809e-05, device='cuda:0')
# val_loss tensor(2.3484e-05, device='cuda:0')
# val_loss tensor(1.1104, device='cuda:0')
# val_loss tensor(0.0006, device='cuda:0')
# val_loss tensor(0.0004, device='cuda:0')
# val_loss tensor(0.2860, device='cuda:0')
# val_loss tensor(0.0001, device='cuda:0')
# val_loss tensor(0.0001, device='cuda:0')
# val_loss tensor(2.2441, device='cuda:0')
# val_loss tensor(0.0038, device='cuda:0')
# val_loss tensor(0.0004, device='cuda:0')
# val_loss tensor(0.0004, device='cuda:0')
# val_loss tensor(0.5201, device='cuda:0')
# val_loss tensor(0.1528, device='cuda:0')
# val_loss tensor(2.5045, device='cuda:0')
# val_loss tensor(0.2925, device='cuda:0')
# val_loss tensor(0.0002, device='cuda:0')
# val_loss tensor(0.0009, device='cuda:0')
# val_loss tensor(0.0996, device='cuda:0')
# val_loss tensor(1.8105, device='cuda:0')
# val_loss tensor(0.0006, device='cuda:0')
# val_loss tensor(7.1642e-05, device='cuda:0')
# val_loss tensor(0.0231, device='cuda:0')
# val_loss tensor(0.0171, device='cuda:0')
# val_loss tensor(0.0083, device='cuda:0')
# val_loss tensor(0.0314, device='cuda:0')
# val_loss tensor(0.0082, device='cuda:0')
# val_loss tensor(0.0006, device='cuda:0')
# val_loss tensor(1.9817, device='cuda:0')
# val_loss tensor(0.0238, device='cuda:0')
# val_loss tensor(0.0057, device='cuda:0')
# val_loss tensor(0., device='cuda:0')
# val_loss tensor(0.0102, device='cuda:0')
# val_loss tensor(0.0175, device='cuda:0')
# val_loss tensor(0.3665, device='cuda:0')
# val_loss tensor(0.1484, device='cuda:0')
# val_loss tensor(0.7889, device='cuda:0')
# val_loss tensor(0.0586, device='cuda:0')
# val_loss tensor(0.0016, device='cuda:0')
# val_loss tensor(0.0031, device='cuda:0')
# val_loss tensor(0.4968, device='cuda:0')
# val_loss tensor(0.0431, device='cuda:0')
# val_loss tensor(2.7769, device='cuda:0')
# val_loss tensor(0.0479, device='cuda:0')
# val_loss tensor(0.0048, device='cuda:0')
# val_loss tensor(1.0729e-06, device='cuda:0')
# val_loss tensor(0.0340, device='cuda:0')
# val_loss tensor(4.7444e-05, device='cuda:0')
# val_loss tensor(0.5143, device='cuda:0')
# val_loss tensor(0.2470, device='cuda:0')
# val_loss tensor(0.0471, device='cuda:0')
# val_loss tensor(0.0144, device='cuda:0')
# val_loss tensor(0.0029, device='cuda:0')
# val_loss tensor(0.0030, device='cuda:0')
# val_loss tensor(0.0057, device='cuda:0')
# val_loss tensor(0.0020, device='cuda:0')
# val_loss tensor(4.6967e-05, device='cuda:0')
# val_loss tensor(5.9605e-07, device='cuda:0')
# val_loss tensor(0.8977, device='cuda:0')
# val_loss tensor(0.8933, device='cuda:0')
# val_loss tensor(0.0636, device='cuda:0')
# val_loss tensor(1.9644, device='cuda:0')
# val_loss tensor(0.0026, device='cuda:0')
# val_loss tensor(0.0001, device='cuda:0')
# val_loss tensor(0.0018, device='cuda:0')
# val_loss tensor(2.3459, device='cuda:0')
# val_loss tensor(0.7881, device='cuda:0')
# val_loss tensor(1.5882, device='cuda:0')
# val_loss tensor(0.2864, device='cuda:0')
# val_loss tensor(0.0334, device='cuda:0')
# val_loss tensor(3.1012, device='cuda:0')
# val_loss tensor(0.0003, device='cuda:0')
# val_loss tensor(0.0788, device='cuda:0')
# val_loss tensor(1.1682e-05, device='cuda:0')
# val_loss tensor(0.0002, device='cuda:0')
# val_loss tensor(0.0008, device='cuda:0')
# val_loss tensor(0.0489, device='cuda:0')
# val_loss tensor(0.0003, device='cuda:0')
# val_loss tensor(0.0004, device='cuda:0')
# val_loss tensor(1.1921e-07, device='cuda:0')
# val_loss tensor(0.5060, device='cuda:0')
# val_loss tensor(0.0043, device='cuda:0')
# val_loss tensor(0.1708, device='cuda:0')
# val_loss tensor(3.6430, device='cuda:0')
# val_loss tensor(0.0351, device='cuda:0')
# val_loss tensor(0.2543, device='cuda:0')
# val_loss tensor(0.1317, device='cuda:0')
# val_loss tensor(0.8989, device='cuda:0')
# val_loss tensor(0.0072, device='cuda:0')
# val_loss tensor(0.4426, device='cuda:0')
# val_loss tensor(8.8569e-05, device='cuda:0')
# val_loss tensor(0.0218, device='cuda:0')
# val_loss tensor(0.3161, device='cuda:0')
# val_loss tensor(0.0009, device='cuda:0')
# val_loss tensor(4.7684e-07, device='cuda:0')
# val_loss tensor(4.5761, device='cuda:0')
# val_loss tensor(0.0044, device='cuda:0')
# val_loss tensor(0.0026, device='cuda:0')
# val_loss tensor(0.0054, device='cuda:0')
# val_loss tensor(1.6194, device='cuda:0')
# val_loss tensor(0.1923, device='cuda:0')
# val_loss tensor(1.5751, device='cuda:0')
# val_loss tensor(0.0287, device='cuda:0')
# val_loss tensor(0.0036, device='cuda:0')
# val_loss tensor(0.9656, device='cuda:0')
# val_loss tensor(5.9988, device='cuda:0')
# val_loss tensor(0.3253, device='cuda:0')
# val_loss tensor(0.1759, device='cuda:0')
# val_loss tensor(0.3593, device='cuda:0')
# val_loss tensor(0.0102, device='cuda:0')
# val_loss tensor(2.8252e-05, device='cuda:0')
# val_loss tensor(0.0154, device='cuda:0')
# val_loss tensor(0.0161, device='cuda:0')
# val_loss tensor(1.1921e-07, device='cuda:0')
# val_loss tensor(4.7684e-07, device='cuda:0')
# val_loss tensor(0.0001, device='cuda:0')
# val_loss tensor(1.5756, device='cuda:0')
# val_loss tensor(0.0360, device='cuda:0')
# val_loss tensor(0.0021, device='cuda:0')
# val_loss tensor(0.0050, device='cuda:0')
# val_loss tensor(1.0621, device='cuda:0')
# val_loss tensor(0.0020, device='cuda:0')
# val_loss tensor(0.0035, device='cuda:0')
# val_loss tensor(0.1336, device='cuda:0')
# val_loss tensor(0.0761, device='cuda:0')
# val_loss tensor(0.0003, device='cuda:0')
# val_loss tensor(0.0282, device='cuda:0')
# val_loss tensor(5.6264, device='cuda:0')
# val_loss tensor(7.1526e-07, device='cuda:0')
# val_loss tensor(1.6849, device='cuda:0')
# val_loss tensor(0.0376, device='cuda:0')
# val_loss tensor(0.1341, device='cuda:0')
# val_loss tensor(0.0950, device='cuda:0')
# val_loss tensor(1.8621, device='cuda:0')
# val_loss tensor(1.5497e-06, device='cuda:0')
# val_loss tensor(0.0614, device='cuda:0')
# val_loss tensor(0.3165, device='cuda:0')
# val_loss tensor(0.1272, device='cuda:0')
# val_loss tensor(0.0001, device='cuda:0')
# val_loss tensor(0.2582, device='cuda:0')
# val_loss tensor(1.4898, device='cuda:0')
# val_loss tensor(0.0236, device='cuda:0')
# val_loss tensor(0.6133, device='cuda:0')
# val_loss tensor(0.0597, device='cuda:0')
# val_loss tensor(2.5804, device='cuda:0')
# val_loss tensor(0., device='cuda:0')
# val_loss tensor(3.5072, device='cuda:0')
# val_loss tensor(0.0010, device='cuda:0')
# val_loss tensor(0.1794, device='cuda:0')
# val_loss tensor(0.0032, device='cuda:0')
# val_loss tensor(2.8768, device='cuda:0')
# val_loss tensor(0.0379, device='cuda:0')
# val_loss tensor(0.6039, device='cuda:0')
# val_loss tensor(0.9920, device='cuda:0')
# val_loss tensor(0.2003, device='cuda:0')
# val_loss tensor(0.0017, device='cuda:0')
# val_loss tensor(0.5506, device='cuda:0')
# val_loss tensor(0.4960, device='cuda:0')
# val_loss tensor(0.0019, device='cuda:0')
# val_loss tensor(0.2132, device='cuda:0')
# val_loss tensor(0.1004, device='cuda:0')
# val_loss tensor(2.9489, device='cuda:0')
# val_loss tensor(3.6198, device='cuda:0')
# val_loss tensor(0.0104, device='cuda:0')
# val_loss tensor(0.0469, device='cuda:0')
# val_loss tensor(0.0328, device='cuda:0')
# val_loss tensor(0.0006, device='cuda:0')
# val_loss tensor(0.0195, device='cuda:0')
# val_loss tensor(5.9605e-07, device='cuda:0')
# val_loss tensor(0.5215, device='cuda:0')
# val_loss tensor(0.4939, device='cuda:0')
# val_loss tensor(0.0004, device='cuda:0')
# val_loss tensor(0.0422, device='cuda:0')
# val_loss tensor(0.0025, device='cuda:0')
# val_loss tensor(2.1662, device='cuda:0')
# val_loss tensor(7.1526e-07, device='cuda:0')
# val_loss tensor(7.9748e-05, device='cuda:0')
# val_loss tensor(0.0112, device='cuda:0')
# val_loss tensor(0.1792, device='cuda:0')
# val_loss tensor(0.0005, device='cuda:0')
# val_loss tensor(0.0004, device='cuda:0')
# val_loss tensor(9.0389, device='cuda:0')
# val_loss tensor(0.0300, device='cuda:0')
# val_loss tensor(4.7247, device='cuda:0')
# val_loss tensor(0.0005, device='cuda:0')
# val_loss tensor(0.0337, device='cuda:0')
# val_loss tensor(0.0073, device='cuda:0')
# val_loss tensor(0.4831, device='cuda:0')
# val_loss tensor(6.4267, device='cuda:0')
# val_loss tensor(0.1742, device='cuda:0')
# val_loss tensor(2.5610, device='cuda:0')
# val_loss tensor(0.1424, device='cuda:0')
# val_loss tensor(0.0334, device='cuda:0')
# val_loss tensor(1.1884, device='cuda:0')
# val_loss tensor(3.0727, device='cuda:0')
# val_loss tensor(0.0451, device='cuda:0')
# val_loss tensor(0.0907, device='cuda:0')
# val_loss tensor(0.2771, device='cuda:0')
# val_loss tensor(0.4704, device='cuda:0')
# val_loss tensor(0.0004, device='cuda:0')
# val_loss tensor(0.0866, device='cuda:0')
# val_loss tensor(0.0016, device='cuda:0')
# val_loss tensor(4.7600, device='cuda:0')
# val_loss tensor(0.0733, device='cuda:0')
# val_loss tensor(0., device='cuda:0')
# val_loss tensor(0.2203, device='cuda:0')
# val_loss tensor(0.0037, device='cuda:0')
# val_loss tensor(1.0473, device='cuda:0')
# val_loss tensor(0.1005, device='cuda:0')
# val_loss tensor(7.7364e-05, device='cuda:0')
# val_loss tensor(0.0549, device='cuda:0')
# val_loss tensor(0.0056, device='cuda:0')
# val_loss tensor(0.1269, device='cuda:0')
# val_loss tensor(1.5798, device='cuda:0')
# val_loss tensor(2.7657, device='cuda:0')
# val_loss tensor(0.0524, device='cuda:0')
# val_loss tensor(0.6175, device='cuda:0')
# val_loss tensor(0.0106, device='cuda:0')
# val_loss tensor(7.3543, device='cuda:0')
# val_loss tensor(1.7971, device='cuda:0')
# val_loss tensor(0.0010, device='cuda:0')
# val_loss tensor(6.8066e-05, device='cuda:0')
# val_loss tensor(0.1560, device='cuda:0')
# val_loss tensor(0.0003, device='cuda:0')
# val_loss tensor(0.1047, device='cuda:0')
# val_loss tensor(0.0970, device='cuda:0')
# val_loss tensor(0.2421, device='cuda:0')
# val_loss tensor(0.9233, device='cuda:0')
# val_loss tensor(3.4604, device='cuda:0')
# val_loss tensor(0.0378, device='cuda:0')
# val_loss tensor(0.1008, device='cuda:0')
# val_loss tensor(0.0006, device='cuda:0')
# val_loss tensor(0.0001, device='cuda:0')
# val_loss tensor(0.2989, device='cuda:0')
# val_loss tensor(0.0458, device='cuda:0')
# val_loss tensor(0.2788, device='cuda:0')
# val_loss tensor(0.0119, device='cuda:0')
# val_loss tensor(0.0069, device='cuda:0')
# val_loss tensor(0.2451, device='cuda:0')
# val_loss tensor(0.0011, device='cuda:0')
# val_loss tensor(6.3995, device='cuda:0')
# val_loss tensor(0.0003, device='cuda:0')
# val_loss tensor(0.1980, device='cuda:0')
# val_loss tensor(1.1563e-05, device='cuda:0')
# val_loss tensor(0.0421, device='cuda:0')
# val_loss tensor(0.1042, device='cuda:0')
# val_loss tensor(0., device='cuda:0')
# val_loss tensor(0.1397, device='cuda:0')
# val_loss tensor(8.0398, device='cuda:0')
# val_loss tensor(4.0263, device='cuda:0')
# val_loss tensor(3.0756e-05, device='cuda:0')
# val_loss tensor(1.0258, device='cuda:0')
# val_loss tensor(0.5260, device='cuda:0')
# val_loss tensor(0.0043, device='cuda:0')
# val_loss tensor(0.3376, device='cuda:0')
# val_loss tensor(0.0006, device='cuda:0')
# val_loss tensor(0.1420, device='cuda:0')
# val_loss tensor(0.7790, device='cuda:0')
# val_loss tensor(0.0020, device='cuda:0')
# val_loss tensor(0.1027, device='cuda:0')
# val_loss tensor(0.0654, device='cuda:0')
# val_loss tensor(5.6073, device='cuda:0')
# val_loss tensor(0.0679, device='cuda:0')
# val_loss tensor(0.2518, device='cuda:0')
# val_loss tensor(0.1668, device='cuda:0')
# val_loss tensor(0.5342, device='cuda:0')
# val_loss tensor(0.0003, device='cuda:0')
# val_loss tensor(0.0026, device='cuda:0')
# val_loss tensor(4.8788, device='cuda:0')
# val_loss tensor(0.8996, device='cuda:0')
# val_loss tensor(0.0004, device='cuda:0')
# val_loss tensor(0.0523, device='cuda:0')
# val_loss tensor(0., device='cuda:0')
# val_loss tensor(3.5873, device='cuda:0')
# val_loss tensor(0.0177, device='cuda:0')
# val_loss tensor(0.2699, device='cuda:0')
# val_loss tensor(0.8987, device='cuda:0')
# val_loss tensor(0.0181, device='cuda:0')
# val_loss tensor(1.7154, device='cuda:0')
# val_loss tensor(0.2555, device='cuda:0')
# val_loss tensor(0.0007, device='cuda:0')
# val_loss tensor(0.1492, device='cuda:0')
# val_loss tensor(0.0931, device='cuda:0')
# val_loss tensor(0.0002, device='cuda:0')
# val_loss tensor(0.3074, device='cuda:0')
# val_loss tensor(0.0065, device='cuda:0')
# val_loss tensor(0.0074, device='cuda:0')
# val_loss tensor(0.0017, device='cuda:0')
# val_loss tensor(1.7996, device='cuda:0')
# val_loss tensor(1.1758, device='cuda:0')
# val_loss tensor(0.0006, device='cuda:0')
# val_loss tensor(0.0167, device='cuda:0')
# val_loss tensor(0.0014, device='cuda:0')
# val_loss tensor(0.0069, device='cuda:0')
# val_loss tensor(4.9947e-05, device='cuda:0')
# val_loss tensor(0., device='cuda:0')
# val_loss tensor(0.0304, device='cuda:0')
# val_loss tensor(0.0008, device='cuda:0')
# val_loss tensor(1.3248, device='cuda:0')
# val_loss tensor(0.0880, device='cuda:0')
# val_loss tensor(0.7434, device='cuda:0')
# val_loss tensor(0.0204, device='cuda:0')
# val_loss tensor(0.0002, device='cuda:0')
# val_loss tensor(8.2931, device='cuda:0')
# val_loss tensor(0.0051, device='cuda:0')
# val_loss tensor(5.0356, device='cuda:0')
# val_loss tensor(0.2687, device='cuda:0')
# val_loss tensor(3.1856, device='cuda:0')
# val_loss tensor(0.0005, device='cuda:0')
# val_loss tensor(9.7751e-06, device='cuda:0')
# val_loss tensor(5.7815e-05, device='cuda:0')
# val_loss tensor(2.4218, device='cuda:0')
# val_loss tensor(0.0004, device='cuda:0')
# val_loss tensor(0.1237, device='cuda:0')
# val_loss tensor(0.0482, device='cuda:0')
# val_loss tensor(0.0007, device='cuda:0')
# val_loss tensor(0.0527, device='cuda:0')
# val_loss tensor(1.1281, device='cuda:0')
# val_loss tensor(0.0079, device='cuda:0')
# val_loss tensor(0.0006, device='cuda:0')
# val_loss tensor(0.0001, device='cuda:0')
# val_loss tensor(0.0039, device='cuda:0')
# val_loss tensor(1.0729e-06, device='cuda:0')
# val_loss tensor(0.6390, device='cuda:0')
# val_loss tensor(0.0013, device='cuda:0')
# val_loss tensor(0.0421, device='cuda:0')
# val_loss tensor(0.0024, device='cuda:0')
# val_loss tensor(0.0670, device='cuda:0')
# val_loss tensor(0.0004, device='cuda:0')
# val_loss tensor(1.3802, device='cuda:0')
# val_loss tensor(0.0247, device='cuda:0')
# val_loss tensor(0.0002, device='cuda:0')
# val_loss tensor(0.0099, device='cuda:0')
# val_loss tensor(0.0004, device='cuda:0')
# val_loss tensor(1.5995, device='cuda:0')
# val_loss tensor(0.0135, device='cuda:0')
# val_loss tensor(0.0068, device='cuda:0')
# val_loss tensor(12.6167, device='cuda:0')
# val_loss tensor(0.0028, device='cuda:0')
# val_loss tensor(0.0082, device='cuda:0')
# val_loss tensor(0.0144, device='cuda:0')
# val_loss tensor(0.7602, device='cuda:0')
# val_loss tensor(0.0091, device='cuda:0')
# val_loss tensor(0.0475, device='cuda:0')
# val_loss tensor(8.4277e-05, device='cuda:0')
# val_loss tensor(0.0139, device='cuda:0')
# val_loss tensor(1.4756, device='cuda:0')
# val_loss tensor(0.0312, device='cuda:0')
# val_loss tensor(0.0015, device='cuda:0')
# val_loss tensor(0.0050, device='cuda:0')
# val_loss tensor(0.0156, device='cuda:0')
# val_loss tensor(0.0332, device='cuda:0')
# val_loss tensor(0.0198, device='cuda:0')
# val_loss tensor(0.0003, device='cuda:0')
# val_loss tensor(0.7744, device='cuda:0')
# val_loss tensor(9.4175e-06, device='cuda:0')
# val_loss tensor(0.0067, device='cuda:0')
# val_loss tensor(0.0001, device='cuda:0')
# val_loss tensor(0.2261, device='cuda:0')
# val_loss tensor(2.4557e-05, device='cuda:0')
# val_loss tensor(0.0004, device='cuda:0')
# val_loss tensor(0.0038, device='cuda:0')
# val_loss tensor(0.0007, device='cuda:0')
# val_loss tensor(0.7225, device='cuda:0')
# val_loss tensor(0.2902, device='cuda:0')
# val_loss tensor(0.0631, device='cuda:0')
# val_loss tensor(1.6309, device='cuda:0')
# val_loss tensor(1.6394, device='cuda:0')
# val_loss tensor(3.4571e-06, device='cuda:0')
# val_loss tensor(0.2747, device='cuda:0')
# val_loss tensor(0., device='cuda:0')
# val_loss tensor(0.3015, device='cuda:0')
# val_loss tensor(0.0115, device='cuda:0')
# val_loss tensor(0.0461, device='cuda:0')
# val_loss tensor(0.0189, device='cuda:0')
# val_loss tensor(0.1805, device='cuda:0')
# val_loss tensor(0.0152, device='cuda:0')
# val_loss tensor(0.0002, device='cuda:0')
# val_loss tensor(0.3761, device='cuda:0')
# val_loss tensor(0.3242, device='cuda:0')
# val_loss tensor(1.2214, device='cuda:0')
# val_loss tensor(0.5847, device='cuda:0')
# val_loss tensor(0.5711, device='cuda:0')
# val_loss tensor(0.9248, device='cuda:0')
# val_loss tensor(5.0067e-05, device='cuda:0')
# val_loss tensor(0.0501, device='cuda:0')
# val_loss tensor(5.4771, device='cuda:0')
# val_loss tensor(0.3239, device='cuda:0')
# val_loss tensor(0.2552, device='cuda:0')
# val_loss tensor(0.0174, device='cuda:0')
# val_loss tensor(0.0110, device='cuda:0')
# val_loss tensor(0.0072, device='cuda:0')
# val_loss tensor(0.0878, device='cuda:0')
# val_loss tensor(0.0047, device='cuda:0')
# val_loss tensor(0.0070, device='cuda:0')
# val_loss tensor(0.0036, device='cuda:0')
# val_loss tensor(3.0743, device='cuda:0')
# val_loss tensor(0.0797, device='cuda:0')
# val_loss tensor(0.3394, device='cuda:0')
# val_loss tensor(0.0007, device='cuda:0')
# val_loss tensor(0.0592, device='cuda:0')
# val_loss tensor(0.5183, device='cuda:0')
# val_loss tensor(2.8211, device='cuda:0')
# val_loss tensor(6.9994, device='cuda:0')
# val_loss tensor(0.0131, device='cuda:0')
# val_loss tensor(0.0072, device='cuda:0')
# val_loss tensor(0.0266, device='cuda:0')
# val_loss tensor(1.5189, device='cuda:0')
# val_loss tensor(0.0034, device='cuda:0')
# val_loss tensor(3.2698, device='cuda:0')
# val_loss tensor(0.0358, device='cuda:0')
# val_loss tensor(0.0959, device='cuda:0')
# val_loss tensor(0.0014, device='cuda:0')
# val_loss tensor(0.0017, device='cuda:0')
# val_loss tensor(0.0437, device='cuda:0')
# val_loss tensor(0.0003, device='cuda:0')
# val_loss tensor(0.2666, device='cuda:0')
# val_loss tensor(0.0116, device='cuda:0')
# val_loss tensor(0.0021, device='cuda:0')
# val_loss tensor(0.0005, device='cuda:0')
# val_loss tensor(0.0011, device='cuda:0')
# val_loss tensor(0.2850, device='cuda:0')
# val_loss tensor(0.0011, device='cuda:0')
# val_loss tensor(0.0357, device='cuda:0')
# val_loss tensor(3.3876, device='cuda:0')
# val_loss tensor(0.0139, device='cuda:0')
# val_loss tensor(0.0002, device='cuda:0')
# val_loss tensor(2.0731, device='cuda:0')
# val_loss tensor(0.4237, device='cuda:0')
# val_loss tensor(2.4438e-05, device='cuda:0')
# val_loss tensor(0.0017, device='cuda:0')
# val_loss tensor(1.4460, device='cuda:0')
# val_loss tensor(0.5890, device='cuda:0')
# val_loss tensor(0.0053, device='cuda:0')
# val_loss tensor(0.6152, device='cuda:0')
# val_loss tensor(0.0005, device='cuda:0')
# val_loss tensor(0.4305, device='cuda:0')
# val_loss tensor(0.0446, device='cuda:0')
# val_loss tensor(0.0400, device='cuda:0')
# val_loss tensor(1.5497e-06, device='cuda:0')
# val_loss tensor(0.2332, device='cuda:0')
# val_loss tensor(0.0007, device='cuda:0')
# val_loss tensor(0.0391, device='cuda:0')
# val_loss tensor(0.0012, device='cuda:0')
# val_loss tensor(0.9097, device='cuda:0')
# val_loss tensor(0.5719, device='cuda:0')
# val_loss tensor(2.3699, device='cuda:0')
# val_loss tensor(1.3416, device='cuda:0')
# val_loss tensor(0.0130, device='cuda:0')
# val_loss tensor(0.0694, device='cuda:0')
# val_loss tensor(0.9189, device='cuda:0')
# val_loss tensor(0.1591, device='cuda:0')
# val_loss tensor(0.0776, device='cuda:0')
# val_loss tensor(9.3813e-05, device='cuda:0')
# val_loss tensor(1.3590e-05, device='cuda:0')
# val_loss tensor(1.2610, device='cuda:0')
# val_loss tensor(2.5090, device='cuda:0')
# val_loss tensor(9.3337e-05, device='cuda:0')
# val_loss tensor(0.1253, device='cuda:0')
# val_loss tensor(0.0016, device='cuda:0')
# val_loss tensor(8.7022e-06, device='cuda:0')
# val_loss tensor(0.1176, device='cuda:0')
# val_loss tensor(0.0010, device='cuda:0')
# val_loss tensor(0.0005, device='cuda:0')
# val_loss tensor(0.1146, device='cuda:0')
# val_loss tensor(0.0005, device='cuda:0')
# val_loss tensor(1.0112, device='cuda:0')
# val_loss tensor(0.0042, device='cuda:0')
# val_loss tensor(0.0036, device='cuda:0')
# val_loss tensor(0.0272, device='cuda:0')
# val_loss tensor(0.0007, device='cuda:0')
# val_loss tensor(0.0041, device='cuda:0')
# val_loss tensor(0.3397, device='cuda:0')
# val_loss tensor(0.0114, device='cuda:0')
# val_loss tensor(0.0607, device='cuda:0')
# val_loss tensor(0.0081, device='cuda:0')
# val_loss tensor(0.0395, device='cuda:0')
# val_loss tensor(4.2915e-06, device='cuda:0')
# val_loss tensor(7.3430e-05, device='cuda:0')
# val_loss tensor(0.0305, device='cuda:0')
# val_loss tensor(1.8765, device='cuda:0')
# val_loss tensor(0.1932, device='cuda:0')
# val_loss tensor(0.0140, device='cuda:0')
# val_loss tensor(0.2077, device='cuda:0')
# val_loss tensor(0.0011, device='cuda:0')
# val_loss tensor(0.0238, device='cuda:0')
# val_loss tensor(0.0340, device='cuda:0')
# val_loss tensor(2.3030, device='cuda:0')
# val_loss tensor(0.0032, device='cuda:0')
# val_loss tensor(0.0040, device='cuda:0')
# val_loss tensor(0.0052, device='cuda:0')
# val_loss tensor(0.3062, device='cuda:0')
# val_loss tensor(0.0736, device='cuda:0')
# val_loss tensor(0.0103, device='cuda:0')
# val_loss tensor(0.0009, device='cuda:0')
# val_loss tensor(0.4821, device='cuda:0')
# val_loss tensor(6.9641, device='cuda:0')
# val_loss tensor(0.4662, device='cuda:0')
# val_loss tensor(0.0002, device='cuda:0')
# val_loss tensor(0.5598, device='cuda:0')
# val_loss tensor(0.0097, device='cuda:0')
# val_loss tensor(1.7567, device='cuda:0')
# val_loss tensor(0.0033, device='cuda:0')
# val_loss tensor(1.2962, device='cuda:0')
# val_loss tensor(0.9063, device='cuda:0')
# val_loss tensor(5.3881e-05, device='cuda:0')
# val_loss tensor(0.0001, device='cuda:0')
# val_loss tensor(0.0043, device='cuda:0')
# val_loss tensor(0.0190, device='cuda:0')
# val_loss tensor(0.1528, device='cuda:0')
# val_loss tensor(2.4039, device='cuda:0')
# val_loss tensor(6.4373e-06, device='cuda:0')
# val_loss tensor(1.1921e-07, device='cuda:0')
# val_loss tensor(1.4099, device='cuda:0')
# val_loss tensor(0.0002, device='cuda:0')
# val_loss tensor(0.0013, device='cuda:0')
# val_loss tensor(0.0659, device='cuda:0')
# val_loss tensor(0.0551, device='cuda:0')
# val_loss tensor(0.0024, device='cuda:0')
# val_loss tensor(0.0026, device='cuda:0')
# val_loss tensor(0.0003, device='cuda:0')
# val_loss tensor(0.0011, device='cuda:0')
# val_loss tensor(1.1921e-07, device='cuda:0')
# val_loss tensor(0.0925, device='cuda:0')
# val_loss tensor(5.4225, device='cuda:0')
# val_loss tensor(0.0005, device='cuda:0')
# val_loss tensor(0.1482, device='cuda:0')
# val_loss tensor(0.0126, device='cuda:0')
# val_loss tensor(0.0005, device='cuda:0')
# val_loss tensor(2.0828, device='cuda:0')
# val_loss tensor(0.3808, device='cuda:0')
# val_loss tensor(4.5895e-05, device='cuda:0')
# val_loss tensor(0.2454, device='cuda:0')
# val_loss tensor(0.3005, device='cuda:0')
# val_loss tensor(0.0437, device='cuda:0')
# val_loss tensor(0.1411, device='cuda:0')
# val_loss tensor(0.4424, device='cuda:0')
# val_loss tensor(0.0002, device='cuda:0')
# val_loss tensor(0.5759, device='cuda:0')
# val_loss tensor(0.0560, device='cuda:0')
# val_loss tensor(1.1532, device='cuda:0')
# val_loss tensor(1.1481, device='cuda:0')
# val_loss tensor(0.0003, device='cuda:0')
# val_loss tensor(0.2044, device='cuda:0')
# val_loss tensor(1.5588, device='cuda:0')
# val_loss tensor(0.0003, device='cuda:0')
# val_loss tensor(4.6513, device='cuda:0')
# val_loss tensor(0.1716, device='cuda:0')
# val_loss tensor(0.0002, device='cuda:0')
# val_loss tensor(0.0114, device='cuda:0')
# val_loss tensor(0.3835, device='cuda:0')
# val_loss tensor(0.0050, device='cuda:0')
# val_loss tensor(0.0830, device='cuda:0')
# val_loss tensor(0.0594, device='cuda:0')
# val_loss tensor(1.9541, device='cuda:0')
# val_loss tensor(9.6197e-05, device='cuda:0')
# val_loss tensor(3.5416, device='cuda:0')
# val_loss tensor(2.0735, device='cuda:0')
# val_loss tensor(0.0015, device='cuda:0')
# val_loss tensor(0.0414, device='cuda:0')
# val_loss tensor(0.1863, device='cuda:0')
# val_loss tensor(0., device='cuda:0')
# val_loss tensor(0.0081, device='cuda:0')
# val_loss tensor(0.1235, device='cuda:0')
# val_loss tensor(0.0013, device='cuda:0')
# val_loss tensor(0.6455, device='cuda:0')
# val_loss tensor(0.0027, device='cuda:0')
# val_loss tensor(0.0014, device='cuda:0')
# val_loss tensor(3.7853, device='cuda:0')
# val_loss tensor(0.0090, device='cuda:0')
# val_loss tensor(0.0210, device='cuda:0')
# val_loss tensor(0.0042, device='cuda:0')
# val_loss tensor(2.1458e-06, device='cuda:0')
# val_loss tensor(0.1886, device='cuda:0')
# val_loss tensor(0.0100, device='cuda:0')
# val_loss tensor(0.1867, device='cuda:0')
# val_loss tensor(0.0003, device='cuda:0')
# val_loss tensor(0.0011, device='cuda:0')
# val_loss tensor(0.4247, device='cuda:0')
# val_loss tensor(0.7689, device='cuda:0')
# val_loss tensor(0.0355, device='cuda:0')
# val_loss tensor(0.0694, device='cuda:0')
# val_loss tensor(3.2544e-05, device='cuda:0')
# val_loss tensor(4.0530e-05, device='cuda:0')
# val_loss tensor(0.4771, device='cuda:0')
# val_loss tensor(3.2278, device='cuda:0')
# val_loss tensor(0.0060, device='cuda:0')
# val_loss tensor(0.1943, device='cuda:0')
# val_loss tensor(0.0507, device='cuda:0')
# val_loss tensor(4.6212, device='cuda:0')
# val_loss tensor(2.4571, device='cuda:0')
# val_loss tensor(0.0004, device='cuda:0')
# val_loss tensor(0.0136, device='cuda:0')
# val_loss tensor(0.1620, device='cuda:0')
# val_loss tensor(0.0221, device='cuda:0')
# val_loss tensor(1.1752, device='cuda:0')
# val_loss tensor(0.0003, device='cuda:0')
# val_loss tensor(0.5603, device='cuda:0')
# val_loss tensor(0.0098, device='cuda:0')
# val_loss tensor(3.1400, device='cuda:0')
# val_loss tensor(0.0876, device='cuda:0')
# val_loss tensor(2.3071, device='cuda:0')
# val_loss tensor(1.4757, device='cuda:0')
# val_loss tensor(0.0001, device='cuda:0')
# val_loss tensor(0.0027, device='cuda:0')
# val_loss tensor(0.0008, device='cuda:0')
# val_loss tensor(0.0019, device='cuda:0')
# val_loss tensor(0.0015, device='cuda:0')
# val_loss tensor(1.8409, device='cuda:0')
# val_loss tensor(0.0001, device='cuda:0')
# val_loss tensor(0.3169, device='cuda:0')
# val_loss tensor(0.0304, device='cuda:0')
# val_loss tensor(0.0012, device='cuda:0')
# val_loss tensor(1.4358, device='cuda:0')
# val_loss tensor(0.0068, device='cuda:0')
# val_loss tensor(0.0045, device='cuda:0')
# val_loss tensor(0.0061, device='cuda:0')
# val_loss tensor(0.0095, device='cuda:0')
# val_loss tensor(0.0220, device='cuda:0')
# val_loss tensor(8.1417e-05, device='cuda:0')
# val_loss tensor(0.7711, device='cuda:0')
# val_loss tensor(0.0990, device='cuda:0')
# val_loss tensor(0.0016, device='cuda:0')
# val_loss tensor(0.0089, device='cuda:0')
# val_loss tensor(0.0043, device='cuda:0')
# val_loss tensor(0.0006, device='cuda:0')
# val_loss tensor(0.1059, device='cuda:0')
# val_loss tensor(1.1812, device='cuda:0')
# val_loss tensor(0.0010, device='cuda:0')
# val_loss tensor(0.0005, device='cuda:0')
# val_loss tensor(0.0012, device='cuda:0')
# val_loss tensor(0.0037, device='cuda:0')
# val_loss tensor(0.0251, device='cuda:0')
# val_loss tensor(0.0004, device='cuda:0')
# val_loss tensor(2.9996, device='cuda:0')
# val_loss tensor(0.0765, device='cuda:0')
# val_loss tensor(0.0001, device='cuda:0')
# val_loss tensor(0.0002, device='cuda:0')
# val_loss tensor(0.4113, device='cuda:0')
# val_loss tensor(0.0010, device='cuda:0')
# val_loss tensor(0.0058, device='cuda:0')
# val_loss tensor(0.1980, device='cuda:0')
# val_loss tensor(0.0010, device='cuda:0')
# val_loss tensor(0.1544, device='cuda:0')
# val_loss tensor(4.7666, device='cuda:0')
# val_loss tensor(0.0264, device='cuda:0')
# val_loss tensor(0.3800, device='cuda:0')
# val_loss tensor(0.1476, device='cuda:0')
# val_loss tensor(0.1190, device='cuda:0')
# val_loss tensor(1.9075, device='cuda:0')
# val_loss tensor(4.4188, device='cuda:0')
# val_loss tensor(0., device='cuda:0')
# val_loss tensor(0.0733, device='cuda:0')
# val_loss tensor(0.0160, device='cuda:0')
# val_loss tensor(0.0007, device='cuda:0')
# val_loss tensor(0.0001, device='cuda:0')
# val_loss tensor(0.1724, device='cuda:0')
# val_loss tensor(0.7002, device='cuda:0')
# val_loss tensor(0.2599, device='cuda:0')
# val_loss tensor(0.1759, device='cuda:0')
# val_loss tensor(0.0116, device='cuda:0')
# val_loss tensor(0.0275, device='cuda:0')
# val_loss tensor(0.0006, device='cuda:0')
# val_loss tensor(4.3902, device='cuda:0')
# val_loss tensor(0.4743, device='cuda:0')
# val_loss tensor(0.0013, device='cuda:0')
# val_loss tensor(3.3987, device='cuda:0')
# val_loss tensor(3.3141, device='cuda:0')
# val_loss tensor(0.1096, device='cuda:0')
# val_loss tensor(1.2755e-05, device='cuda:0')
# val_loss tensor(2.5169, device='cuda:0')
# val_loss tensor(0.0050, device='cuda:0')
# val_loss tensor(0.1436, device='cuda:0')
# val_loss tensor(0.0001, device='cuda:0')
# val_loss tensor(0.8283, device='cuda:0')
# val_loss tensor(0.0004, device='cuda:0')
# val_loss tensor(0.0196, device='cuda:0')
# val_loss tensor(0.0776, device='cuda:0')
# val_loss tensor(1.6928e-05, device='cuda:0')
# val_loss tensor(0.0381, device='cuda:0')
# val_loss tensor(0.0315, device='cuda:0')
# val_loss tensor(0.6639, device='cuda:0')
# val_loss tensor(5.5623, device='cuda:0')
# val_loss tensor(0.0212, device='cuda:0')
# val_loss tensor(0.0001, device='cuda:0')
# val_loss tensor(0.1937, device='cuda:0')
# val_loss tensor(0.0099, device='cuda:0')
# val_loss tensor(1.0190, device='cuda:0')
# val_loss tensor(0.0083, device='cuda:0')
# val_loss tensor(1.5152, device='cuda:0')
# val_loss tensor(0.0826, device='cuda:0')
# val_loss tensor(1.7994, device='cuda:0')
# val_loss tensor(0.0869, device='cuda:0')
# val_loss tensor(0.0050, device='cuda:0')
# val_loss tensor(0.6736, device='cuda:0')
# val_loss tensor(1.1921e-07, device='cuda:0')
# val_loss tensor(0.0014, device='cuda:0')
# val_loss tensor(0.0003, device='cuda:0')
# val_loss tensor(0.0040, device='cuda:0')
# val_loss tensor(0.0011, device='cuda:0')
# val_loss tensor(0.0102, device='cuda:0')
# val_loss tensor(0.0023, device='cuda:0')
# val_loss tensor(5.2490, device='cuda:0')
# val_loss tensor(0.0073, device='cuda:0')
# val_loss tensor(0., device='cuda:0')
# val_loss tensor(0.0533, device='cuda:0')
# val_loss tensor(0.0040, device='cuda:0')
# val_loss tensor(0.0002, device='cuda:0')
# val_loss tensor(0.0378, device='cuda:0')
# val_loss tensor(1.7181, device='cuda:0')
# val_loss tensor(6.6834, device='cuda:0')
# val_loss tensor(0.6584, device='cuda:0')
# val_loss tensor(0.1460, device='cuda:0')
# val_loss tensor(0.0294, device='cuda:0')
# val_loss tensor(0.6410, device='cuda:0')
# val_loss tensor(0.0018, device='cuda:0')
# val_loss tensor(0.0050, device='cuda:0')
# val_loss tensor(0.0004, device='cuda:0')
# val_loss tensor(0.0003, device='cuda:0')
# val_loss tensor(8.2254e-06, device='cuda:0')
# val_loss tensor(0.0926, device='cuda:0')
# val_loss tensor(0.4583, device='cuda:0')
# val_loss tensor(0.0429, device='cuda:0')
# val_loss tensor(0.0166, device='cuda:0')
# val_loss tensor(0.0026, device='cuda:0')
# val_loss tensor(0.0274, device='cuda:0')
# val_loss tensor(0.0214, device='cuda:0')
# val_loss tensor(0.0534, device='cuda:0')
# val_loss tensor(0.9564, device='cuda:0')
# val_loss tensor(0.0014, device='cuda:0')
# val_loss tensor(0.0051, device='cuda:0')
# val_loss tensor(1.3666, device='cuda:0')
# val_loss tensor(0.0017, device='cuda:0')
# val_loss tensor(0.0011, device='cuda:0')
# val_loss tensor(1.1634, device='cuda:0')
# val_loss tensor(0.0524, device='cuda:0')
# val_loss tensor(0.0173, device='cuda:0')
# val_loss tensor(0.0001, device='cuda:0')
# val_loss tensor(0.1507, device='cuda:0')
# val_loss tensor(0.1808, device='cuda:0')
# val_loss tensor(0.0812, device='cuda:0')
# val_loss tensor(2.0877, device='cuda:0')
# val_loss tensor(0.0366, device='cuda:0')
# val_loss tensor(0.0806, device='cuda:0')
# val_loss tensor(1.5616e-05, device='cuda:0')
# val_loss tensor(0.0779, device='cuda:0')
# val_loss tensor(0.0076, device='cuda:0')
# val_loss tensor(0.1802, device='cuda:0')
# val_loss tensor(0.0018, device='cuda:0')
# val_loss tensor(0.0023, device='cuda:0')
# val_loss tensor(3.7743, device='cuda:0')
# val_loss tensor(1.8709, device='cuda:0')
# val_loss tensor(1.7684, device='cuda:0')
# val_loss tensor(0.0005, device='cuda:0')
# val_loss tensor(6.8305e-05, device='cuda:0')
# val_loss tensor(0.0715, device='cuda:0')
# val_loss tensor(0.0683, device='cuda:0')
# val_loss tensor(0.0656, device='cuda:0')
# val_loss tensor(4.1723e-06, device='cuda:0')
# val_loss tensor(0.2290, device='cuda:0')
# val_loss tensor(0.0099, device='cuda:0')
# val_loss tensor(6.1310, device='cuda:0')
# val_loss tensor(0.7561, device='cuda:0')
# val_loss tensor(0.0257, device='cuda:0')
# val_loss tensor(0.7268, device='cuda:0')
# val_loss tensor(0.0003, device='cuda:0')
# val_loss tensor(0.0522, device='cuda:0')
# val_loss tensor(0.0013, device='cuda:0')
# val_loss tensor(0.5799, device='cuda:0')
# val_loss tensor(0.0588, device='cuda:0')
# val_loss tensor(2.6303, device='cuda:0')
# val_loss tensor(0.0009, device='cuda:0')
# val_loss tensor(0.1696, device='cuda:0')
# val_loss tensor(0.0059, device='cuda:0')
# val_loss tensor(0.0405, device='cuda:0')
# val_loss tensor(0.0034, device='cuda:0')
# val_loss tensor(0.7329, device='cuda:0')
# val_loss tensor(0.0001, device='cuda:0')
# val_loss tensor(0.0017, device='cuda:0')
# val_loss tensor(0.6343, device='cuda:0')
# val_loss tensor(0.0011, device='cuda:0')
# val_loss tensor(0.0032, device='cuda:0')
# val_loss tensor(0.0082, device='cuda:0')
# val_loss tensor(0.1584, device='cuda:0')
# val_loss tensor(0.0251, device='cuda:0')
# val_loss tensor(0.4154, device='cuda:0')
# val_loss tensor(0.0010, device='cuda:0')
# val_loss tensor(0.0151, device='cuda:0')
# val_loss tensor(0.0009, device='cuda:0')
# val_loss tensor(0.0030, device='cuda:0')
# val_loss tensor(0.3335, device='cuda:0')
# val_loss tensor(0.0032, device='cuda:0')
# val_loss tensor(0.0359, device='cuda:0')
# val_loss tensor(0.3155, device='cuda:0')
# val_loss tensor(0.0063, device='cuda:0')
# val_loss tensor(0.0209, device='cuda:0')
# val_loss tensor(0.4760, device='cuda:0')
# val_loss tensor(0.8521, device='cuda:0')
# val_loss tensor(0.0743, device='cuda:0')
# val_loss tensor(0.4127, device='cuda:0')
# val_loss tensor(1.7762e-05, device='cuda:0')
# val_loss tensor(0.0044, device='cuda:0')
# val_loss tensor(9.5367e-07, device='cuda:0')
# val_loss tensor(0.0005, device='cuda:0')
# val_loss tensor(2.1243, device='cuda:0')
# val_loss tensor(0.5558, device='cuda:0')
# val_loss tensor(0.5624, device='cuda:0')
# val_loss tensor(0.0404, device='cuda:0')
# val_loss tensor(4.3158, device='cuda:0')
# val_loss tensor(0.0190, device='cuda:0')
# val_loss tensor(0.0001, device='cuda:0')
# val_loss tensor(0.1243, device='cuda:0')
# val_loss tensor(0.0117, device='cuda:0')
# val_loss tensor(1.3068, device='cuda:0')
# val_loss tensor(0.0276, device='cuda:0')
# val_loss tensor(0., device='cuda:0')
# val_loss tensor(0.0152, device='cuda:0')
# val_loss tensor(0.0355, device='cuda:0')
# val_loss tensor(0.0004, device='cuda:0')
# val_loss tensor(0.0033, device='cuda:0')
# val_loss tensor(0.0741, device='cuda:0')
# val_loss tensor(0.0203, device='cuda:0')
# val_loss tensor(0.0076, device='cuda:0')
# val_loss tensor(0.0025, device='cuda:0')
# val_loss tensor(0.2731, device='cuda:0')
# val_loss tensor(0.0140, device='cuda:0')
# val_loss tensor(0.2984, device='cuda:0')
# val_loss tensor(0.0192, device='cuda:0')
# val_loss tensor(0.0517, device='cuda:0')
# val_loss tensor(0.0058, device='cuda:0')
# val_loss tensor(0.1236, device='cuda:0')
# val_loss tensor(0.0478, device='cuda:0')
# val_loss tensor(6.0519, device='cuda:0')
# val_loss tensor(0.0077, device='cuda:0')
# val_loss tensor(0.7603, device='cuda:0')
# val_loss tensor(0.0903, device='cuda:0')
# val_loss tensor(0.0181, device='cuda:0')
# val_loss tensor(0.0080, device='cuda:0')
# val_loss tensor(0.0004, device='cuda:0')
# val_loss tensor(6.9587, device='cuda:0')
# val_loss tensor(0.1344, device='cuda:0')
# val_loss tensor(2.2942, device='cuda:0')
# val_loss tensor(0.0085, device='cuda:0')
# val_loss tensor(0.7158, device='cuda:0')
# val_loss tensor(0.4526, device='cuda:0')
# val_loss tensor(0.0238, device='cuda:0')
# val_loss tensor(1.7071, device='cuda:0')
# val_loss tensor(0.0360, device='cuda:0')
# val_loss tensor(1.7881e-06, device='cuda:0')
# val_loss tensor(0.1884, device='cuda:0')
# val_loss tensor(2.7275, device='cuda:0')
# val_loss tensor(0.2241, device='cuda:0')
# val_loss tensor(0.0013, device='cuda:0')
# val_loss tensor(0.0003, device='cuda:0')
# val_loss tensor(0.0135, device='cuda:0')
# val_loss tensor(0.0010, device='cuda:0')
# val_loss tensor(2.9098, device='cuda:0')
# val_loss tensor(0.0002, device='cuda:0')
# val_loss tensor(0.0006, device='cuda:0')
# val_loss tensor(0.0012, device='cuda:0')
# val_loss tensor(0.0001, device='cuda:0')
# val_loss tensor(0.5056, device='cuda:0')
# val_loss tensor(0.0522, device='cuda:0')
# val_loss tensor(0.0094, device='cuda:0')
# val_loss tensor(0.0003, device='cuda:0')
# val_loss tensor(1.5639, device='cuda:0')
# val_loss tensor(0.0019, device='cuda:0')
# val_loss tensor(0.0055, device='cuda:0')
# val_loss tensor(0.2478, device='cuda:0')
# val_loss tensor(1.1921e-07, device='cuda:0')
# val_loss tensor(0.0352, device='cuda:0')
# val_loss tensor(4.1355, device='cuda:0')
# val_loss tensor(1.7598, device='cuda:0')
# val_loss tensor(4.8723, device='cuda:0')
# val_loss tensor(0.0014, device='cuda:0')
# val_loss tensor(0.0025, device='cuda:0')
# val_loss tensor(2.8062, device='cuda:0')
# val_loss tensor(0.0114, device='cuda:0')
# val_loss tensor(1.0798, device='cuda:0')
# val_loss tensor(0.0018, device='cuda:0')
# val_loss tensor(1.2330, device='cuda:0')
# val_loss tensor(0.0004, device='cuda:0')
# val_loss tensor(0.6470, device='cuda:0')
# val_loss tensor(1.8550, device='cuda:0')
# val_loss tensor(0.0017, device='cuda:0')
# val_loss tensor(0.2542, device='cuda:0')
# val_loss tensor(0.1475, device='cuda:0')
# val_loss tensor(0.0240, device='cuda:0')
# val_loss tensor(5.6035, device='cuda:0')
# val_loss tensor(0.0107, device='cuda:0')
# val_loss tensor(0.3613, device='cuda:0')
# val_loss tensor(0.0672, device='cuda:0')
# val_loss tensor(0.0016, device='cuda:0')
# val_loss tensor(6.5205e-05, device='cuda:0')
# val_loss tensor(0.9256, device='cuda:0')
# val_loss tensor(0.0067, device='cuda:0')
# val_loss tensor(3.8874, device='cuda:0')
# val_loss tensor(0.2412, device='cuda:0')
# val_loss tensor(1.1650, device='cuda:0')
# val_loss tensor(0.1281, device='cuda:0')
# val_loss tensor(0.1862, device='cuda:0')
# val_loss tensor(9.2145e-05, device='cuda:0')
# val_loss tensor(0.0074, device='cuda:0')
# val_loss tensor(2.9825, device='cuda:0')
# val_loss tensor(0.7129, device='cuda:0')
# val_loss tensor(0.0016, device='cuda:0')
# val_loss tensor(1.3456, device='cuda:0')
# val_loss tensor(0.0759, device='cuda:0')
# val_loss tensor(0.0104, device='cuda:0')
# val_loss tensor(1.5462, device='cuda:0')
# val_loss tensor(3.3971, device='cuda:0')
# val_loss tensor(4.2795e-05, device='cuda:0')
# val_loss tensor(0.0364, device='cuda:0')
# val_loss tensor(0.0119, device='cuda:0')
# val_loss tensor(0.2069, device='cuda:0')
# val_loss tensor(0.0870, device='cuda:0')
# val_loss tensor(0.0003, device='cuda:0')
# val_loss tensor(0.0012, device='cuda:0')
# val_loss tensor(0.2421, device='cuda:0')
# val_loss tensor(0.0147, device='cuda:0')
# val_loss tensor(0.0012, device='cuda:0')
# val_loss tensor(0.0003, device='cuda:0')
# val_loss tensor(0.2168, device='cuda:0')
# val_loss tensor(1.0580, device='cuda:0')
# val_loss tensor(0.0183, device='cuda:0')
# val_loss tensor(0.0378, device='cuda:0')
# val_loss tensor(0.0183, device='cuda:0')
# val_loss tensor(0.0026, device='cuda:0')
# val_loss tensor(0.1597, device='cuda:0')
# val_loss tensor(0.0275, device='cuda:0')
# val_loss tensor(0.0031, device='cuda:0')
# val_loss tensor(6.3298e-05, device='cuda:0')
# val_loss tensor(2.3069, device='cuda:0')
# val_loss tensor(1.2113, device='cuda:0')
# val_loss tensor(3.3519, device='cuda:0')
# val_loss tensor(1.6101, device='cuda:0')
# val_loss tensor(0.0002, device='cuda:0')
# val_loss tensor(0.2603, device='cuda:0')
# val_loss tensor(0.1945, device='cuda:0')
# val_loss tensor(0.0080, device='cuda:0')
# val_loss tensor(1.2868, device='cuda:0')
# val_loss tensor(0.9954, device='cuda:0')
# val_loss tensor(0.0186, device='cuda:0')
# val_loss tensor(1.6228, device='cuda:0')
# val_loss tensor(0.1027, device='cuda:0')
# val_loss tensor(5.5193, device='cuda:0')
# val_loss tensor(2.8610e-06, device='cuda:0')
# val_loss tensor(0.3542, device='cuda:0')
# val_loss tensor(0.1505, device='cuda:0')
# val_loss tensor(0.0158, device='cuda:0')
# val_loss tensor(0.0701, device='cuda:0')
# val_loss tensor(9.5367e-07, device='cuda:0')
# val_loss tensor(2.3739, device='cuda:0')
# val_loss tensor(0.0010, device='cuda:0')
# val_loss tensor(0.0012, device='cuda:0')
# val_loss tensor(0.0544, device='cuda:0')
# val_loss tensor(0.0002, device='cuda:0')
# val_loss tensor(0.0059, device='cuda:0')
# val_loss tensor(3.4084, device='cuda:0')
# val_loss tensor(0.0910, device='cuda:0')
# val_loss tensor(0.0014, device='cuda:0')
# val_loss tensor(0.5163, device='cuda:0')
# val_loss tensor(0.0200, device='cuda:0')
# val_loss tensor(0.1250, device='cuda:0')
# val_loss tensor(0.0155, device='cuda:0')
# val_loss tensor(0.4223, device='cuda:0')
# val_loss tensor(0.0001, device='cuda:0')
# val_loss tensor(0.0011, device='cuda:0')
# val_loss tensor(0.0009, device='cuda:0')
# val_loss tensor(3.3966, device='cuda:0')
# val_loss tensor(0.0010, device='cuda:0')
# val_loss tensor(0.0155, device='cuda:0')
# val_loss tensor(1.1117, device='cuda:0')
# val_loss tensor(0.1288, device='cuda:0')
# val_loss tensor(0.0062, device='cuda:0')
# val_loss tensor(8.3442, device='cuda:0')
# val_loss tensor(0.0008, device='cuda:0')
# val_loss tensor(5.4836e-06, device='cuda:0')
# val_loss tensor(0.0861, device='cuda:0')
# val_loss tensor(0.6848, device='cuda:0')
# val_loss tensor(0.9101, device='cuda:0')
# val_loss tensor(0.0055, device='cuda:0')
# val_loss tensor(0.5059, device='cuda:0')
# val_loss tensor(0.0005, device='cuda:0')
# val_loss tensor(0.0002, device='cuda:0')
# val_loss tensor(0.0012, device='cuda:0')
# val_loss tensor(0.9807, device='cuda:0')
# val_loss tensor(0.0041, device='cuda:0')
# val_loss tensor(1.6306, device='cuda:0')
# val_loss tensor(0.0139, device='cuda:0')
# val_loss tensor(0.0798, device='cuda:0')
# val_loss tensor(0.2051, device='cuda:0')
# val_loss tensor(3.7332, device='cuda:0')
# val_loss tensor(0.4275, device='cuda:0')
# val_loss tensor(6.0170, device='cuda:0')
# val_loss tensor(0.0291, device='cuda:0')
# val_loss tensor(0., device='cuda:0')
# val_loss tensor(0.0398, device='cuda:0')
# val_loss tensor(0.0003, device='cuda:0')
# val_loss tensor(0.0177, device='cuda:0')
# val_loss tensor(0.0396, device='cuda:0')
# val_loss tensor(0.8738, device='cuda:0')
# val_loss tensor(3.8411, device='cuda:0')
# val_loss tensor(0.0013, device='cuda:0')
# val_loss tensor(0.3748, device='cuda:0')
# val_loss tensor(0.0141, device='cuda:0')
# val_loss tensor(0.0194, device='cuda:0')
# val_loss tensor(6.5658, device='cuda:0')
# val_loss tensor(0.0434, device='cuda:0')
# val_loss tensor(0.0196, device='cuda:0')
# val_loss tensor(0.9606, device='cuda:0')
# val_loss tensor(0.5069, device='cuda:0')
# val_loss tensor(1.7219, device='cuda:0')
# val_loss tensor(0.5860, device='cuda:0')
# val_loss tensor(0.0854, device='cuda:0')
# val_loss tensor(0.0362, device='cuda:0')
# val_loss tensor(1.2681, device='cuda:0')
# val_loss tensor(3.7743, device='cuda:0')
# val_loss tensor(1.1563e-05, device='cuda:0')
# val_loss tensor(0.0002, device='cuda:0')
# val_loss tensor(4.2962, device='cuda:0')
# val_loss tensor(0.1329, device='cuda:0')
# val_loss tensor(7.5102e-06, device='cuda:0')
# val_loss tensor(0.2687, device='cuda:0')
# val_loss tensor(0.9158, device='cuda:0')
# val_loss tensor(0.4923, device='cuda:0')
# ...
# val_loss tensor(0.0007, device='cuda:0')
# val_loss tensor(0.8344, device='cuda:0')
# val_loss tensor(1.7898, device='cuda:0')
# val_loss tensor(1.7404e-05, device='cuda:0')
# val_loss tensor(0., device='cuda:0')
# val_loss tensor(0.0507, device='cuda:0')
# val_loss tensor(2.9075, device='cuda:0')
# val_loss tensor(0.0004, device='cuda:0')
# val_loss tensor(0.0136, device='cuda:0')
# val_loss tensor(3.8147e-06, device='cuda:0')
# val_loss tensor(0.1188, device='cuda:0')
# val_loss tensor(0.0658, device='cuda:0')
# val_loss tensor(0.3833, device='cuda:0')
# val_loss tensor(1.3113e-06, device='cuda:0')
# val_loss tensor(0.2941, device='cuda:0')
# val_loss tensor(0.0039, device='cuda:0')
# val_loss tensor(0.8292, device='cuda:0')
# val_loss tensor(5.3644e-06, device='cuda:0')
# val_loss tensor(0.3948, device='cuda:0')
# val_loss tensor(0.1027, device='cuda:0')
# val_loss tensor(0.0407, device='cuda:0')
# val_loss tensor(0.0181, device='cuda:0')
# val_loss tensor(0.3829, device='cuda:0')
# val_loss tensor(0.0295, device='cuda:0')
# val_loss tensor(0.0090, device='cuda:0')
# val_loss tensor(0.0505, device='cuda:0')
# val_loss tensor(0.0133, device='cuda:0')
# val_loss tensor(0.9305, device='cuda:0')
# val_loss tensor(0.0002, device='cuda:0')
# val_loss tensor(0.0003, device='cuda:0')
# val_loss tensor(0.0126, device='cuda:0')
# val_loss tensor(1.7708, device='cuda:0')
# val_loss tensor(0.5291, device='cuda:0')
# val_loss tensor(5.7220e-06, device='cuda:0')
# val_loss tensor(0.0002, device='cuda:0')
# val_loss tensor(0.0029, device='cuda:0')
# val_loss tensor(0.0034, device='cuda:0')
# val_loss tensor(1.6064, device='cuda:0')
# val_loss tensor(0.0057, device='cuda:0')
# val_loss tensor(0.0452, device='cuda:0')
# val_loss tensor(0.1300, device='cuda:0')
# val_loss tensor(0.2013, device='cuda:0')
# val_loss tensor(0.0012, device='cuda:0')
# val_loss tensor(0.0122, device='cuda:0')
# val_loss tensor(0.0735, device='cuda:0')
# val_loss tensor(0.0007, device='cuda:0')
# val_loss tensor(0.0408, device='cuda:0')
# val_loss tensor(0.0029, device='cuda:0')
# val_loss tensor(1.5259e-05, device='cuda:0')
# val_loss tensor(0.0003, device='cuda:0')
# val_loss tensor(3.5241, device='cuda:0')
# val_loss tensor(0.0153, device='cuda:0')
# val_loss tensor(0.2405, device='cuda:0')
# val_loss tensor(0.6988, device='cuda:0')
# val_loss tensor(0.8050, device='cuda:0')
# val_loss tensor(0.0142, device='cuda:0')
# val_loss tensor(0.1760, device='cuda:0')
# val_loss tensor(2.7418e-06, device='cuda:0')
# val_loss tensor(2.8523, device='cuda:0')
# val_loss tensor(1.1921e-07, device='cuda:0')
# val_loss tensor(2.3546, device='cuda:0')
# val_loss tensor(0.0351, device='cuda:0')
# val_loss tensor(0.0011, device='cuda:0')
# val_loss tensor(0.0005, device='cuda:0')
# val_loss tensor(0.0082, device='cuda:0')
# val_loss tensor(0.0036, device='cuda:0')
# val_loss tensor(2.6106e-05, device='cuda:0')
# val_loss tensor(0.0960, device='cuda:0')
# val_loss tensor(0.0012, device='cuda:0')
# val_loss tensor(0.0038, device='cuda:0')
# val_loss tensor(0.0021, device='cuda:0')
# val_loss tensor(0.0084, device='cuda:0')
# val_loss tensor(0.0103, device='cuda:0')
# val_loss tensor(0.0194, device='cuda:0')
# val_loss tensor(0.0073, device='cuda:0')
# val_loss tensor(1.0621, device='cuda:0')
# val_loss tensor(0.0092, device='cuda:0')
# val_loss tensor(3.2505, device='cuda:0')
# val_loss tensor(0.0006, device='cuda:0')
# val_loss tensor(0.0022, device='cuda:0')
# val_loss tensor(1.7719, device='cuda:0')
# val_loss tensor(0.0003, device='cuda:0')
# val_loss tensor(0.0122, device='cuda:0')
# val_loss tensor(2.4470, device='cuda:0')
# val_loss tensor(0.0466, device='cuda:0')
# val_loss tensor(6.5565e-06, device='cuda:0')
# val_loss tensor(0.1499, device='cuda:0')
# val_loss tensor(1.7881e-06, device='cuda:0')
# val_loss tensor(0.0023, device='cuda:0')
# val_loss tensor(0.0007, device='cuda:0')
# val_loss tensor(0.3042, device='cuda:0')
# val_loss tensor(2.0427, device='cuda:0')
# val_loss tensor(0.0023, device='cuda:0')
# val_loss tensor(0.7230, device='cuda:0')
# val_loss tensor(1.7050, device='cuda:0')
# val_loss tensor(0.0970, device='cuda:0')
# val_loss tensor(1.2922, device='cuda:0')
# val_loss tensor(0.0056, device='cuda:0')
# val_loss tensor(0.0172, device='cuda:0')
# val_loss tensor(0.0004, device='cuda:0')
# val_loss tensor(0.9663, device='cuda:0')
# val_loss tensor(0.0043, device='cuda:0')
# val_loss tensor(2.8824, device='cuda:0')
# val_loss tensor(0.0315, device='cuda:0')
# val_loss tensor(0.0169, device='cuda:0')
# val_loss tensor(0.0261, device='cuda:0')
# val_loss tensor(8.6900e-05, device='cuda:0')
# val_loss tensor(1.1921e-06, device='cuda:0')
# val_loss tensor(0.1927, device='cuda:0')
# val_loss tensor(0.0013, device='cuda:0')
# val_loss tensor(0.0003, device='cuda:0')
# val_loss tensor(0.0003, device='cuda:0')
# val_loss tensor(0.0002, device='cuda:0')
# val_loss tensor(0.0299, device='cuda:0')
# val_loss tensor(0.1186, device='cuda:0')
# val_loss tensor(0.0300, device='cuda:0')
# val_loss tensor(5.9960e-05, device='cuda:0')
# val_loss tensor(0.0007, device='cuda:0')
# val_loss tensor(0.0140, device='cuda:0')
# val_loss tensor(0.1598, device='cuda:0')
# val_loss tensor(3.4576, device='cuda:0')
# val_loss tensor(0.0020, device='cuda:0')
# val_loss tensor(0.0064, device='cuda:0')
# val_loss tensor(0.3880, device='cuda:0')
# val_loss tensor(0.0791, device='cuda:0')
# val_loss tensor(0.0171, device='cuda:0')
# val_loss tensor(1.4996, device='cuda:0')
# val_loss tensor(0.3108, device='cuda:0')
# val_loss tensor(6.4717, device='cuda:0')
# val_loss tensor(0.1883, device='cuda:0')
# val_loss tensor(0.0512, device='cuda:0')
# val_loss tensor(0.0058, device='cuda:0')
# val_loss tensor(0.0024, device='cuda:0')
# val_loss tensor(0.1738, device='cuda:0')
# val_loss tensor(0.0569, device='cuda:0')
# val_loss tensor(3.1206, device='cuda:0')
# val_loss tensor(0.0971, device='cuda:0')
# val_loss tensor(0.0034, device='cuda:0')
# val_loss tensor(1.1921e-07, device='cuda:0')
# val_loss tensor(0.1088, device='cuda:0')
# val_loss tensor(0.0001, device='cuda:0')
# val_loss tensor(0.8143, device='cuda:0')
# val_loss tensor(0.2821, device='cuda:0')
# val_loss tensor(0.5155, device='cuda:0')
# val_loss tensor(0.2133, device='cuda:0')
# val_loss tensor(0.0596, device='cuda:0')
# val_loss tensor(1.3708, device='cuda:0')
# val_loss tensor(3.2079, device='cuda:0')
# val_loss tensor(0.0685, device='cuda:0')
# val_loss tensor(4.3259, device='cuda:0')
# val_loss tensor(0.0013, device='cuda:0')
# val_loss tensor(2.5987e-05, device='cuda:0')
# val_loss tensor(0.1900, device='cuda:0')
# val_loss tensor(1.2165, device='cuda:0')
# val_loss tensor(0.0004, device='cuda:0')
# val_loss tensor(1.3321, device='cuda:0')
# val_loss tensor(0.0067, device='cuda:0')
# val_loss tensor(0.2184, device='cuda:0')
# val_loss tensor(11.2888, device='cuda:0')
# val_loss tensor(0.0020, device='cuda:0')
# val_loss tensor(1.6918, device='cuda:0')
# val_loss tensor(0.1910, device='cuda:0')
# val_loss tensor(0.0261, device='cuda:0')
# val_loss tensor(0.0096, device='cuda:0')
# val_loss tensor(0.2274, device='cuda:0')
# val_loss tensor(3.6955e-06, device='cuda:0')
# val_loss tensor(0.0021, device='cuda:0')
# val_loss tensor(0.1413, device='cuda:0')
# val_loss tensor(1.7881e-06, device='cuda:0')
# val_loss tensor(0.0001, device='cuda:0')
# val_loss tensor(0.0162, device='cuda:0')
# val_loss tensor(0.0705, device='cuda:0')
# val_loss tensor(0.0774, device='cuda:0')
# val_loss tensor(0.0052, device='cuda:0')
# val_loss tensor(0.0052, device='cuda:0')
# val_loss tensor(0.4319, device='cuda:0')
# val_loss tensor(0.7941, device='cuda:0')
# val_loss tensor(0.0029, device='cuda:0')
# val_loss tensor(0.3600, device='cuda:0')
# val_loss tensor(0.5724, device='cuda:0')
# val_loss tensor(0.0024, device='cuda:0')
# val_loss tensor(0.0141, device='cuda:0')
# val_loss tensor(0.0001, device='cuda:0')
# val_loss tensor(0.9724, device='cuda:0')
# val_loss tensor(0.0024, device='cuda:0')
# val_loss tensor(0.0059, device='cuda:0')
# val_loss tensor(0.7401, device='cuda:0')
# val_loss tensor(0.0009, device='cuda:0')
# val_loss tensor(0.0212, device='cuda:0')
# val_loss tensor(0.0013, device='cuda:0')
# val_loss tensor(0.0045, device='cuda:0')
# val_loss tensor(0.0015, device='cuda:0')
# val_loss tensor(0.0764, device='cuda:0')
# val_loss tensor(0.0031, device='cuda:0')
# val_loss tensor(5.3170, device='cuda:0')
# val_loss tensor(0.0028, device='cuda:0')
# val_loss tensor(0.1223, device='cuda:0')
# val_loss tensor(0.0006, device='cuda:0')
# val_loss tensor(0.5750, device='cuda:0')
# val_loss tensor(0.4438, device='cuda:0')
# val_loss tensor(0.0020, device='cuda:0')
# val_loss tensor(0.0013, device='cuda:0')
# val_loss tensor(0.0521, device='cuda:0')
# val_loss tensor(0.2793, device='cuda:0')
# val_loss tensor(0.0002, device='cuda:0')
# val_loss tensor(0.0004, device='cuda:0')
# val_loss tensor(0.0668, device='cuda:0')
# val_loss tensor(0.0064, device='cuda:0')
# val_loss tensor(0., device='cuda:0')
# val_loss tensor(3.7606, device='cuda:0')
# val_loss tensor(0.0034, device='cuda:0')
# val_loss tensor(0.0009, device='cuda:0')
# val_loss tensor(0.0067, device='cuda:0')
# val_loss tensor(0.0319, device='cuda:0')
# val_loss tensor(0.0009, device='cuda:0')
# val_loss tensor(0.8857, device='cuda:0')
# val_loss tensor(0.0072, device='cuda:0')
# val_loss tensor(1.1138, device='cuda:0')
# val_loss tensor(0.0021, device='cuda:0')
# val_loss tensor(0.0001, device='cuda:0')
# val_loss tensor(0.0750, device='cuda:0')
# val_loss tensor(0.4846, device='cuda:0')
# val_loss tensor(0.0001, device='cuda:0')
# val_loss tensor(0.5243, device='cuda:0')
# val_loss tensor(0.6925, device='cuda:0')
# val_loss tensor(1.6296, device='cuda:0')
# val_loss tensor(2.4053, device='cuda:0')
# val_loss tensor(7.7721e-05, device='cuda:0')
# val_loss tensor(0.5994, device='cuda:0')
# val_loss tensor(0.0953, device='cuda:0')
# val_loss tensor(5.1216, device='cuda:0')
# val_loss tensor(0.0529, device='cuda:0')
# val_loss tensor(0.0080, device='cuda:0')
# val_loss tensor(0.2375, device='cuda:0')
# val_loss tensor(0.0005, device='cuda:0')
# val_loss tensor(0.1056, device='cuda:0')
# val_loss tensor(0.1532, device='cuda:0')
# val_loss tensor(0.0009, device='cuda:0')
# val_loss tensor(0.0024, device='cuda:0')
# val_loss tensor(0.0762, device='cuda:0')
# val_loss tensor(0.0080, device='cuda:0')
# val_loss tensor(1.6851, device='cuda:0')
# val_loss tensor(0.0193, device='cuda:0')
# val_loss tensor(0.0029, device='cuda:0')
# val_loss tensor(0.0711, device='cuda:0')
# val_loss tensor(0.0032, device='cuda:0')
# val_loss tensor(0., device='cuda:0')
# val_loss tensor(0.0011, device='cuda:0')
# val_loss tensor(0.0051, device='cuda:0')
# val_loss tensor(3.0894, device='cuda:0')
# val_loss tensor(0.0103, device='cuda:0')
# val_loss tensor(0.0018, device='cuda:0')
# val_loss tensor(0.1299, device='cuda:0')
# val_loss tensor(0.0104, device='cuda:0')
# val_loss tensor(5.3644e-06, device='cuda:0')
# val_loss tensor(0.0013, device='cuda:0')
# val_loss tensor(0.0787, device='cuda:0')
# val_loss tensor(0.2189, device='cuda:0')
# val_loss tensor(0.0125, device='cuda:0')
# val_loss tensor(0.0239, device='cuda:0')
# val_loss tensor(0.0573, device='cuda:0')
# val_loss tensor(0.0001, device='cuda:0')
# val_loss tensor(0.1475, device='cuda:0')
# val_loss tensor(0.5871, device='cuda:0')
# val_loss tensor(1.5238, device='cuda:0')
# val_loss tensor(0.4328, device='cuda:0')
# val_loss tensor(0.1117, device='cuda:0')
# val_loss tensor(0.1664, device='cuda:0')
# val_loss tensor(0.0293, device='cuda:0')
# val_loss tensor(0.0029, device='cuda:0')
# val_loss tensor(0.1040, device='cuda:0')
# val_loss tensor(0.6415, device='cuda:0')
# val_loss tensor(0.0005, device='cuda:0')
# val_loss tensor(0.2739, device='cuda:0')
# val_loss tensor(0.0389, device='cuda:0')
# val_loss tensor(0.0005, device='cuda:0')
# val_loss tensor(0.0074, device='cuda:0')
# val_loss tensor(0.8849, device='cuda:0')
# val_loss tensor(0.0002, device='cuda:0')
# val_loss tensor(0.0330, device='cuda:0')
# val_loss tensor(0.0116, device='cuda:0')
# val_loss tensor(0.0026, device='cuda:0')
# val_loss tensor(0.0031, device='cuda:0')
# val_loss tensor(0.0676, device='cuda:0')
# val_loss tensor(0.3065, device='cuda:0')
# val_loss tensor(0.0315, device='cuda:0')
# val_loss tensor(1.1921e-07, device='cuda:0')
# val_loss tensor(0.0215, device='cuda:0')
# val_loss tensor(0.0009, device='cuda:0')
# val_loss tensor(0.0011, device='cuda:0')
# val_loss tensor(0.4399, device='cuda:0')
# val_loss tensor(0.0032, device='cuda:0')
# val_loss tensor(0.0015, device='cuda:0')
# val_loss tensor(0.0033, device='cuda:0')
# val_loss tensor(0.2595, device='cuda:0')
# val_loss tensor(0.0008, device='cuda:0')
# val_loss tensor(1.7028, device='cuda:0')
# val_loss tensor(0.0019, device='cuda:0')
# val_loss tensor(0.1225, device='cuda:0')
# val_loss tensor(0.5221, device='cuda:0')
# val_loss tensor(0.0165, device='cuda:0')
# val_loss tensor(0.0304, device='cuda:0')
# val_loss tensor(0.4508, device='cuda:0')
# val_loss tensor(0.0508, device='cuda:0')
# val_loss tensor(0.0008, device='cuda:0')
# val_loss tensor(0.3706, device='cuda:0')
# val_loss tensor(1.1702, device='cuda:0')
# val_loss tensor(0.0002, device='cuda:0')
# val_loss tensor(0.0106, device='cuda:0')
# val_loss tensor(0.0046, device='cuda:0')
# val_loss tensor(0.0075, device='cuda:0')
# val_loss tensor(0.2785, device='cuda:0')
# val_loss tensor(3.3354, device='cuda:0')
# val_loss tensor(4.2660, device='cuda:0')
# val_loss tensor(0.2748, device='cuda:0')
# val_loss tensor(0.0013, device='cuda:0')
# val_loss tensor(4.7684e-07, device='cuda:0')
# val_loss tensor(0.1191, device='cuda:0')
# val_loss tensor(0.0026, device='cuda:0')
# val_loss tensor(0.0879, device='cuda:0')
# val_loss tensor(0.0461, device='cuda:0')
# val_loss tensor(0.0617, device='cuda:0')
# val_loss tensor(5.9603e-05, device='cuda:0')
# val_loss tensor(0.7829, device='cuda:0')
# val_loss tensor(1.2516, device='cuda:0')
# val_loss tensor(0.0006, device='cuda:0')
# val_loss tensor(0.0386, device='cuda:0')
# val_loss tensor(0.0002, device='cuda:0')
# val_loss tensor(6.1868e-05, device='cuda:0')
# val_loss tensor(0.0002, device='cuda:0')
# val_loss tensor(2.3575, device='cuda:0')
# val_loss tensor(3.8981e-05, device='cuda:0')
# val_loss tensor(0.0089, device='cuda:0')
# val_loss tensor(0.0004, device='cuda:0')
# val_loss tensor(0.4625, device='cuda:0')
# val_loss tensor(1.5443, device='cuda:0')
# val_loss tensor(0.3014, device='cuda:0')
# val_loss tensor(0.0003, device='cuda:0')
# val_loss tensor(0.7843, device='cuda:0')
# val_loss tensor(0.0009, device='cuda:0')
# val_loss tensor(0., device='cuda:0')
# val_loss tensor(0.0449, device='cuda:0')
# val_loss tensor(0.2118, device='cuda:0')
# val_loss tensor(0.0346, device='cuda:0')
# val_loss tensor(0.0002, device='cuda:0')
# val_loss tensor(3.7312e-05, device='cuda:0')
# val_loss tensor(0.3333, device='cuda:0')
# val_loss tensor(0.0429, device='cuda:0')
# val_loss tensor(0.0066, device='cuda:0')
# val_loss tensor(0.3989, device='cuda:0')
# val_loss tensor(0.3169, device='cuda:0')
# val_loss tensor(0.0078, device='cuda:0')
# val_loss tensor(0.1138, device='cuda:0')
# val_loss tensor(0.3965, device='cuda:0')
# val_loss tensor(0.0011, device='cuda:0')
# val_loss tensor(0.0079, device='cuda:0')
# val_loss tensor(1.9398, device='cuda:0')
# val_loss tensor(0.2469, device='cuda:0')
# val_loss tensor(0.1969, device='cuda:0')
# val_loss tensor(0.0088, device='cuda:0')
# val_loss tensor(0.0002, device='cuda:0')
# val_loss tensor(0.0024, device='cuda:0')
# val_loss tensor(0.0056, device='cuda:0')
# val_loss tensor(0.4440, device='cuda:0')
# val_loss tensor(0.0003, device='cuda:0')
# val_loss tensor(0.0028, device='cuda:0')
# val_loss tensor(0.0013, device='cuda:0')
# val_loss tensor(0.8410, device='cuda:0')
# val_loss tensor(1.5808, device='cuda:0')
# val_loss tensor(0.0010, device='cuda:0')
# val_loss tensor(0.0503, device='cuda:0')
# val_loss tensor(0.1999, device='cuda:0')
# val_loss tensor(0.0059, device='cuda:0')
# val_loss tensor(4.3886, device='cuda:0')
# val_loss tensor(0.1220, device='cuda:0')
# val_loss tensor(0.0003, device='cuda:0')
# val_loss tensor(0.0138, device='cuda:0')
# val_loss tensor(0.0050, device='cuda:0')
# val_loss tensor(0.7265, device='cuda:0')
# val_loss tensor(1.8318, device='cuda:0')
# val_loss tensor(0.1318, device='cuda:0')
# val_loss tensor(0.0144, device='cuda:0')
# val_loss tensor(0.0991, device='cuda:0')
# val_loss tensor(0.0130, device='cuda:0')
# val_loss tensor(2.8929, device='cuda:0')
# val_loss tensor(8.0484, device='cuda:0')
# val_loss tensor(0.0158, device='cuda:0')
# val_loss tensor(0.0086, device='cuda:0')

# %%
trainer.validate(model=model,dataloaders=train_dl)

# %%
# !ls lightning_logs/version_3
# Out:
# checkpoints
# events.out.tfevents.1637489077.DESKTOP-0QH3RIG.2552.0
# hparams.yaml

# %%
# %load_ext tensorboard

# %%
# %tensorboard --log_dir lightning_logs/
# Out:
# ERROR: Failed to launch TensorBoard (exited with 1).
# Contents of stderr:
# TensorFlow installation not found - running with reduced feature set.
# Error: A logdir or db must be specified. For example `tensorboard --logdir mylogdir` or `tensorboard --db sqlite:~/.tensorboard.db`. Run `tensorboard --helpfull` for details and examples.
